# %%
# import opensim as osim
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from data_utils import *

# %%
data_dir = '../data/'

# load the data
grf_data = np.load(data_dir + 'grf.npy', mmap_mode='r')
muscle_data = np.load(data_dir + 'muscle.npy', mmap_mode='r')

grf_labels = ['GRF_x', 'GRF_y', 'GRF_z']
muscle_labels = ['tibpost', 'tibant', 'edl', 'ehl', 'fdl', 'fhl', 'perbrev', 'perlong', 'achilles']

grf_dict = {0: 'GRF_x', 1: 'GRF_y', 2: 'GRF_z'}
muscle_dict = {0: 'tibpost', 1: 'tibant', 2: 'edl', 3: 'ehl', 4: 'fdl', 5: 'fhl', 6: 'perbrev', 7: 'perlong', 8: 'achilles'}

# %%
data = np.concatenate((grf_data, muscle_data), axis=2)
# print(data.shape)

np.random.seed(42)
np.random.shuffle(data)

# %%
num_samples = data.shape[0]
train_size = int(0.8 * num_samples)
val_size = int(0.1 * num_samples)

print(f"Number of samples: {num_samples}")
print(f"Train size: {train_size}")
print(f"Validation size: {val_size}")
# Out:
# Number of samples: 13388
# Train size: 10710
# Validation size: 1338

# %%
train_data = data[:train_size]
val_data = data[train_size:train_size+val_size]
test_data = data[train_size+val_size:]

print(f"Train data shape: {train_data.shape}")
print(f"Validation data shape: {val_data.shape}")
print(f"Test data shape: {test_data.shape}")
# Out:
# Train data shape: (10710, 100, 12)
# Validation data shape: (1338, 100, 12)
# Test data shape: (1340, 100, 12)

# %%
X_train, y_train = train_data[:, :, :3], train_data[:, :, 3:]
X_val, y_val = val_data[:, :, :3], val_data[:, :, 3:]
X_test, y_test = test_data[:, :, :3], test_data[:, :, 3:]

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (10710, 100, 3)
# y_train shape: (10710, 100, 9)
# X_val shape: (1338, 100, 3)
# y_val shape: (1338, 100, 9)
# X_test shape: (1340, 100, 3)
# y_test shape: (1340, 100, 9)

# %%
figure = plt.figure(figsize=(10, 10))

num_achilles_segments = len(y_train[:, :, 8])
perc_stance = np.linspace(0, 1, 100)

for i in range(num_achilles_segments):
    plt.plot(perc_stance, y_train[i, :, 8], linewidth=2)

plt.ylabel("Achilles Muscle Force (N)", fontsize=18)
plt.xlabel("Percent Normalized Stance (%)", fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
# Out:
# (array([-1000.,     0.,  1000.,  2000.,  3000.,  4000.,  5000.]),
#  [Text(0, -1000.0, '−1000'),
#   Text(0, 0.0, '0'),
#   Text(0, 1000.0, '1000'),
#   Text(0, 2000.0, '2000'),
#   Text(0, 3000.0, '3000'),
#   Text(0, 4000.0, '4000'),
#   Text(0, 5000.0, '5000')])

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

class TransformerModel(nn.Module):
    def __init__(self, input_dim, output_dim, d_model, nhead, num_encoder_layers, dim_feedforward, dropout):
        super(TransformerModel, self).__init__()
        
        self.input_embedding = nn.Linear(input_dim, d_model)
        # self.positional_encoding = nn.Parameter(self._generate_positional_encoding(d_model, max_len=100))
        self.register_buffer("positional_encoding", self._generate_positional_encoding(d_model, max_len=100))

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead, 
            dim_feedforward=dim_feedforward, 
            dropout=dropout,
            batch_first=True
        )
        
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_encoder_layers)
        self.output_layer = nn.Linear(d_model, output_dim)

    def forward(self, x):
        # Input shape: (batch_size, sequence_length, input_dim)
        seq_len = x.size(1)
        x = self.input_embedding(x)  # (batch_size, sequence_length, d_model)
        
        x = x + self.positional_encoding[:, :seq_len, :].to(x.device)  # Add positional encoding
        
        x = self.transformer_encoder(x)  # (sequence_length, batch_size, d_model)
        
        output = self.output_layer(x)  # (batch_size, sequence_length, output_dim)
        
        return output

    @staticmethod
    def _generate_positional_encoding(d_model, max_len=100):
        position = torch.arange(0, max_len).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2) * -(torch.log1p(torch.tensor(10000.0)) / d_model))
        
        pe = torch.zeros(max_len, d_model)
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        
        return pe.unsqueeze(0)  # Add batch dimension

# %%
# define device (GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cuda

# %%
from torch.utils.data import TensorDataset, DataLoader

# convert your data to torch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).to(device)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32).to(device)

# create torch datasets
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

# # create dataloaders from datasets
# train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
# val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)

# %%
def train_eval(train_dataset, val_dataset, d_model, num_heads, num_encoder_layers, dim_feedforward,
               dropout_rate, learning_rate, batch_size, regularization, num_epochs=50):
    # prepare DataLoader with the specified batch size
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size)
    
    # initialize the model
    model = TransformerModel(input_dim=3,
                             output_dim=9, 
                             d_model=d_model, 
                             nhead=num_heads, 
                             num_encoder_layers=num_encoder_layers, 
                             dim_feedforward=dim_feedforward, 
                             dropout=dropout_rate)
    
    # move the model to the device
    model.to(device)    
    
    # initialize the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=regularization)
    
    # early stopping setup
    patience = 10
    best_val_loss = float('inf')
    epochs_without_improvement = 0

    # training loop
    for epoch in range(num_epochs):
        # set the model to train mode
        model.train()
        
        # initialize training loss
        train_loss = 0.0

        # iterate over the training data
        for X_batch, y_batch in train_loader:
            # zero the gradients
            optimizer.zero_grad()
            
            # forward pass
            outputs = model(X_batch)
            
            # calculate the loss
            loss = criterion(outputs, y_batch)
            
            # backward pass and optimization
            loss.backward()
            optimizer.step()
            
            # update training loss
            train_loss += loss.item() * X_batch.size(0)
        
        # average training loss over all samples
        train_loss /= len(train_loader.dataset)
        
        # validation step
        # set the model to evaluation mode
        model.eval()
        
        # initialize validation loss
        val_loss = 0.0
        
        # turn off gradients for validation
        with torch.no_grad():
            # iterate over the validation data
            for X_batch, y_batch in val_loader:
                # forward pass
                outputs = model(X_batch)
                
                # calculate the loss
                loss = criterion(outputs, y_batch)
                
                # update validation loss
                val_loss += loss.item() * X_batch.size(0)

        # average validation loss over all samples
        val_loss /= len(val_loader.dataset)
        
        # # print progress
        # if (epoch + 1) % 10 == 0:
        #     print(f"Epoch [{epoch + 1}/{num_epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        # early stopping check
        if val_loss < best_val_loss:
            # save best validation loss
            best_val_loss = val_loss
            
            # reset epochs without improvement
            epochs_without_improvement = 0
            
            # save the best model
            # torch.save(model.state_dict(), 'best_model.pth')
            best_model_state_dict = model.state_dict()
        else:
            # increment epochs without improvement
            epochs_without_improvement += 1

        # break if patience limit is reached
        if epochs_without_improvement >= patience:
            break

    # load the best model's state for this set of hyperparameters
    # model.load_state_dict(torch.load('best_model.pth'))
    model.load_state_dict(best_model_state_dict)
    
    # return the best validation loss
    return best_val_loss, model

# %%
import optuna

def objective(trial):
    # Sample hyperparameters
    d_model = trial.suggest_categorical('d_model', [32, 64, 128])
    num_heads = trial.suggest_categorical('num_heads', [2, 4, 8])
    num_encoder_layers = trial.suggest_categorical('num_encoder_layers', [2, 4, 6])
    dim_feedforward = trial.suggest_categorical('dim_feedforward', [64, 128, 256])
    dropout_rate = trial.suggest_float('dropout_rate', 0.0, 0.5, log=False)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-2, log=True)
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128])
    regularization = trial.suggest_float('regularization', 1e-5, 1e-2, log=True)

    # Train and evaluate with these hyperparameters
    val_loss, _ = train_eval(train_dataset, val_dataset, d_model, num_heads, num_encoder_layers, dim_feedforward, 
                   dropout_rate, learning_rate, batch_size, regularization, num_epochs=500)
    
    # Return the validation loss (minimize this value)
    return val_loss

# %%
# Define the study
study = optuna.create_study(direction="minimize")  # Minimize validation loss

# Start the optimization
study.optimize(objective, n_trials=100)  # Run 100 trials
# Out:
# [I 2024-11-26 16:44:45,728] A new study created in memory with name: no-name-f4f828c3-40a7-40df-bbc2-9c108c55eeaf
# [I 2024-11-26 16:48:50,422] Trial 0 finished with value: 93789.02741965621 and parameters: {'d_model': 128, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.04117020483663619, 'learning_rate': 0.0017044731999422442, 'batch_size': 128, 'regularization': 0.0001613989100456791}. Best is trial 0 with value: 93789.02741965621.
# [I 2024-11-26 16:58:30,359] Trial 1 finished with value: 3396.4953463658444 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 64, 'dropout_rate': 0.4305776707147756, 'learning_rate': 0.0009411992780526087, 'batch_size': 128, 'regularization': 0.0010826603742184343}. Best is trial 1 with value: 3396.4953463658444.
# [I 2024-11-26 16:59:25,971] Trial 2 finished with value: 85057.21915872571 and parameters: {'d_model': 32, 'num_heads': 2, 'num_encoder_layers': 6, 'dim_feedforward': 128, 'dropout_rate': 0.37269971877378255, 'learning_rate': 0.0037543946569339208, 'batch_size': 128, 'regularization': 9.698119123553432e-05}. Best is trial 1 with value: 3396.4953463658444.
# [I 2024-11-26 17:03:00,182] Trial 3 finished with value: 13199.834813504298 and parameters: {'d_model': 128, 'num_heads': 4, 'num_encoder_layers': 2, 'dim_feedforward': 64, 'dropout_rate': 0.358161605866971, 'learning_rate': 0.00015523043735951445, 'batch_size': 32, 'regularization': 0.0001351820887975179}. Best is trial 1 with value: 3396.4953463658444.
# [I 2024-11-26 17:18:50,165] Trial 4 finished with value: 134712.90321375188 and parameters: {'d_model': 128, 'num_heads': 4, 'num_encoder_layers': 2, 'dim_feedforward': 128, 'dropout_rate': 0.4123120967283036, 'learning_rate': 2.9673096400012422e-05, 'batch_size': 128, 'regularization': 0.0012755910549008332}. Best is trial 1 with value: 3396.4953463658444.
# [I 2024-11-26 17:20:21,838] Trial 5 finished with value: 14330.109474261959 and parameters: {'d_model': 32, 'num_heads': 4, 'num_encoder_layers': 6, 'dim_feedforward': 128, 'dropout_rate': 0.37156092603167984, 'learning_rate': 0.0036223123960700317, 'batch_size': 64, 'regularization': 0.0004542547776938187}. Best is trial 1 with value: 3396.4953463658444.
# [I 2024-11-26 17:28:02,771] Trial 6 finished with value: 1473.463487109083 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.11950471378766475, 'learning_rate': 0.0010243683624814699, 'batch_size': 64, 'regularization': 0.0016001257455908865}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 17:31:52,136] Trial 7 finished with value: 10753.295037194039 and parameters: {'d_model': 128, 'num_heads': 4, 'num_encoder_layers': 2, 'dim_feedforward': 64, 'dropout_rate': 0.40534261368863383, 'learning_rate': 0.00018678617473212873, 'batch_size': 32, 'regularization': 0.0055700534002658415}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 17:34:11,191] Trial 8 finished with value: 96349.54023028775 and parameters: {'d_model': 128, 'num_heads': 4, 'num_encoder_layers': 4, 'dim_feedforward': 64, 'dropout_rate': 0.12420037038196258, 'learning_rate': 0.0019426080396579921, 'batch_size': 32, 'regularization': 5.6862008463985425e-05}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 17:44:28,395] Trial 9 finished with value: 19810.273014176943 and parameters: {'d_model': 32, 'num_heads': 2, 'num_encoder_layers': 2, 'dim_feedforward': 256, 'dropout_rate': 0.4127719058961341, 'learning_rate': 8.165545882957057e-05, 'batch_size': 64, 'regularization': 2.1486597508212945e-05}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 18:19:21,852] Trial 10 finished with value: 215150.45424607623 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.20774200422213074, 'learning_rate': 1.0904053961204741e-05, 'batch_size': 64, 'regularization': 0.009616709964867997}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 18:24:55,130] Trial 11 finished with value: 16033.953524967303 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 64, 'dropout_rate': 0.4961513451921368, 'learning_rate': 0.0006984270268773341, 'batch_size': 64, 'regularization': 0.0015780301844384105}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 18:38:01,842] Trial 12 finished with value: 2442.9841137074927 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 128, 'dropout_rate': 0.2552134489255058, 'learning_rate': 0.0006282741541147261, 'batch_size': 128, 'regularization': 0.0012225300486288424}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 18:46:59,449] Trial 13 finished with value: 7186.858951676943 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.23920312371448943, 'learning_rate': 0.0004650298637843116, 'batch_size': 128, 'regularization': 0.003133699111899821}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 19:00:43,583] Trial 14 finished with value: 1705.5542382666526 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 128, 'dropout_rate': 0.14099182334159657, 'learning_rate': 0.0003270008424027713, 'batch_size': 64, 'regularization': 0.00048679447147338174}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 19:01:55,893] Trial 15 finished with value: 96348.50038536996 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.008532262885732167, 'learning_rate': 0.0080386330644017, 'batch_size': 64, 'regularization': 0.000462427618557143}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 19:11:16,589] Trial 16 finished with value: 3780.6990092780734 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.131671735804195, 'learning_rate': 0.00023005471293987824, 'batch_size': 64, 'regularization': 0.0002939574918876825}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 19:43:00,762] Trial 17 finished with value: 2596.0814860390974 and parameters: {'d_model': 64, 'num_heads': 2, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.10002428363700519, 'learning_rate': 6.86836974116886e-05, 'batch_size': 64, 'regularization': 0.003283037689389931}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 19:50:27,420] Trial 18 finished with value: 4897.065728933109 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.19875996737224727, 'learning_rate': 0.00034226382165868595, 'batch_size': 64, 'regularization': 1.2969623206183943e-05}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 19:55:51,393] Trial 19 finished with value: 1548.6139722519035 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 128, 'dropout_rate': 0.07653473429435015, 'learning_rate': 0.001542571299065039, 'batch_size': 64, 'regularization': 0.0007459794684590834}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 19:56:52,787] Trial 20 finished with value: 96350.3718936846 and parameters: {'d_model': 64, 'num_heads': 2, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.060698005424526386, 'learning_rate': 0.009000068101993478, 'batch_size': 64, 'regularization': 0.0025152017552607336}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 20:02:58,471] Trial 21 finished with value: 2149.5804943318503 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 128, 'dropout_rate': 0.16707175067667274, 'learning_rate': 0.0013711790634116957, 'batch_size': 64, 'regularization': 0.0005968773750258387}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 20:04:44,720] Trial 22 finished with value: 96349.51040498879 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 128, 'dropout_rate': 0.08572493001988664, 'learning_rate': 0.002805160185769755, 'batch_size': 64, 'regularization': 0.00025453313411526234}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 20:12:42,074] Trial 23 finished with value: 2367.5883442375516 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 128, 'dropout_rate': 0.2793999531800561, 'learning_rate': 0.0009037141632682067, 'batch_size': 64, 'regularization': 0.0007325166508456613}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 20:27:37,904] Trial 24 finished with value: 1503.8241218601106 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 128, 'dropout_rate': 0.15293346900952764, 'learning_rate': 0.00037152413585297793, 'batch_size': 64, 'regularization': 0.0006827123306636483}. Best is trial 6 with value: 1473.463487109083.
# [I 2024-11-26 20:49:32,867] Trial 25 finished with value: 1288.6177192083567 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.022952244151204587, 'learning_rate': 0.00010859473305214566, 'batch_size': 32, 'regularization': 0.0017701668690853693}. Best is trial 25 with value: 1288.6177192083567.
# [I 2024-11-26 21:15:45,356] Trial 26 finished with value: 1156.3821041637473 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.00806973588204743, 'learning_rate': 9.61536150128281e-05, 'batch_size': 32, 'regularization': 0.0021455125318276553}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-26 21:39:41,119] Trial 27 finished with value: 1162.0247779013687 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.001500655565811887, 'learning_rate': 9.442137067222387e-05, 'batch_size': 32, 'regularization': 0.005425402567861678}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-26 21:59:14,794] Trial 28 finished with value: 1240.5603251777957 and parameters: {'d_model': 64, 'num_heads': 2, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.0012431573406643283, 'learning_rate': 8.120052373889476e-05, 'batch_size': 32, 'regularization': 0.006328401560795785}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-26 22:36:51,403] Trial 29 finished with value: 3101.267746724355 and parameters: {'d_model': 32, 'num_heads': 2, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.04956117675762669, 'learning_rate': 4.083926206196309e-05, 'batch_size': 32, 'regularization': 0.007127290819358798}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-26 23:12:49,805] Trial 30 finished with value: 1338.8593963486196 and parameters: {'d_model': 128, 'num_heads': 2, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.004140148472147286, 'learning_rate': 3.6453183855903644e-05, 'batch_size': 32, 'regularization': 0.0045438022158433775}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-26 23:30:28,482] Trial 31 finished with value: 1784.3781951767446 and parameters: {'d_model': 64, 'num_heads': 2, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.03154830952792113, 'learning_rate': 8.269239171102046e-05, 'batch_size': 32, 'regularization': 0.002289469473099125}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-26 23:42:20,587] Trial 32 finished with value: 1500.3182717909192 and parameters: {'d_model': 64, 'num_heads': 2, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.03397205503246574, 'learning_rate': 0.00014553346662338491, 'batch_size': 32, 'regularization': 0.005106602154234189}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 00:35:54,634] Trial 33 finished with value: 51651.86551756353 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.009861104069859516, 'learning_rate': 1.6947934162077553e-05, 'batch_size': 32, 'regularization': 0.009607443497713655}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 00:59:42,741] Trial 34 finished with value: 3987.255776170123 and parameters: {'d_model': 32, 'num_heads': 2, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.04952380306113385, 'learning_rate': 5.870849990306686e-05, 'batch_size': 32, 'regularization': 0.0034388934814814746}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 01:20:02,488] Trial 35 finished with value: 1272.747079253375 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 64, 'dropout_rate': 0.0028027618940482534, 'learning_rate': 0.00011492517343070131, 'batch_size': 32, 'regularization': 0.0022042596617375346}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 01:30:53,808] Trial 36 finished with value: 2881.18404225348 and parameters: {'d_model': 64, 'num_heads': 4, 'num_encoder_layers': 4, 'dim_feedforward': 64, 'dropout_rate': 0.07330376234098374, 'learning_rate': 0.00012743313170877836, 'batch_size': 32, 'regularization': 0.005673556249857218}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 02:18:26,692] Trial 37 finished with value: 2869.1388003316515 and parameters: {'d_model': 128, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 64, 'dropout_rate': 0.0982857308164553, 'learning_rate': 2.6891406711448845e-05, 'batch_size': 32, 'regularization': 0.0009771565271315867}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 02:24:30,918] Trial 38 finished with value: 4015.7962064415174 and parameters: {'d_model': 32, 'num_heads': 2, 'num_encoder_layers': 2, 'dim_feedforward': 64, 'dropout_rate': 0.04043363203914231, 'learning_rate': 0.00022589066552909496, 'batch_size': 32, 'regularization': 0.0023529297068791695}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 02:43:27,198] Trial 39 finished with value: 9651.014809008315 and parameters: {'d_model': 64, 'num_heads': 4, 'num_encoder_layers': 4, 'dim_feedforward': 64, 'dropout_rate': 0.3332868726846716, 'learning_rate': 5.152948659596512e-05, 'batch_size': 32, 'regularization': 0.007768402775407565}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 03:36:13,891] Trial 40 finished with value: 1414.7491953212584 and parameters: {'d_model': 128, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 64, 'dropout_rate': 0.0041517023327866664, 'learning_rate': 2.343601901967667e-05, 'batch_size': 32, 'regularization': 0.0038891410537103058}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 03:52:42,614] Trial 41 finished with value: 1499.5203667656367 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.03122587281088363, 'learning_rate': 0.00010755775440652732, 'batch_size': 32, 'regularization': 0.0016941118752996308}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 04:13:17,965] Trial 42 finished with value: 1607.8852446004414 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 64, 'dropout_rate': 0.025347316554869145, 'learning_rate': 9.825695659727232e-05, 'batch_size': 32, 'regularization': 0.0019341005454592073}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 04:25:05,482] Trial 43 finished with value: 1867.4304978352134 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.06090266415346944, 'learning_rate': 0.0001780483186110947, 'batch_size': 32, 'regularization': 0.006454746552434878}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 04:40:11,893] Trial 44 finished with value: 4467.529128275644 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 2, 'dim_feedforward': 256, 'dropout_rate': 0.10313667758519349, 'learning_rate': 5.7004658853156994e-05, 'batch_size': 32, 'regularization': 0.0011634580448308355}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 05:12:11,270] Trial 45 finished with value: 2783.0868064070673 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.020881175660846164, 'learning_rate': 0.00010507904133817422, 'batch_size': 128, 'regularization': 0.0026248469993680077}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 05:26:23,586] Trial 46 finished with value: 1403.6998603033912 and parameters: {'d_model': 32, 'num_heads': 4, 'num_encoder_layers': 4, 'dim_feedforward': 64, 'dropout_rate': 0.003951303994219531, 'learning_rate': 0.00023061464295537058, 'batch_size': 32, 'regularization': 0.00010811281198395548}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 05:59:22,230] Trial 47 finished with value: 2307.8714951770366 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.06540571911202049, 'learning_rate': 4.630769515852038e-05, 'batch_size': 32, 'regularization': 6.152885638173812e-05}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 06:10:12,403] Trial 48 finished with value: 13647.012147911995 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 2, 'dim_feedforward': 128, 'dropout_rate': 0.4909151455598063, 'learning_rate': 7.451087546785295e-05, 'batch_size': 32, 'regularization': 0.003976485939932892}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 06:32:52,666] Trial 49 finished with value: 1630.68701171875 and parameters: {'d_model': 128, 'num_heads': 2, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.04484220515427975, 'learning_rate': 0.0001379809668299102, 'batch_size': 128, 'regularization': 0.0014544426595247053}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 07:10:30,448] Trial 50 finished with value: 4190.962499416106 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 64, 'dropout_rate': 0.1118590433738707, 'learning_rate': 3.563652884969321e-05, 'batch_size': 32, 'regularization': 0.0009555493824520486}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 08:00:45,738] Trial 51 finished with value: 25076.73388452915 and parameters: {'d_model': 128, 'num_heads': 2, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.006634823628192234, 'learning_rate': 1.3598240182464552e-05, 'batch_size': 32, 'regularization': 0.004624916691771782}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 08:38:01,895] Trial 52 finished with value: 1564.201217126775 and parameters: {'d_model': 128, 'num_heads': 2, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.022263465105962457, 'learning_rate': 3.091578182011075e-05, 'batch_size': 32, 'regularization': 0.004284478693060457}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 08:47:00,060] Trial 53 finished with value: 1575.5454791287136 and parameters: {'d_model': 128, 'num_heads': 2, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.0006226780166542559, 'learning_rate': 8.449654817592226e-05, 'batch_size': 32, 'regularization': 0.008700664652155988}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 09:14:01,249] Trial 54 finished with value: 5370.981293500094 and parameters: {'d_model': 128, 'num_heads': 2, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.08177625625638364, 'learning_rate': 1.9129712997264964e-05, 'batch_size': 32, 'regularization': 0.002800748885907156}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 09:24:22,983] Trial 55 finished with value: 2541.936397900318 and parameters: {'d_model': 128, 'num_heads': 2, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.053423311939052684, 'learning_rate': 6.32178684230776e-05, 'batch_size': 32, 'regularization': 0.001965183532143209}. Best is trial 26 with value: 1156.3821041637473.
# [I 2024-11-27 09:33:16,928] Trial 56 finished with value: 1154.2830688294096 and parameters: {'d_model': 64, 'num_heads': 4, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.023243335447013132, 'learning_rate': 0.00026030351173767614, 'batch_size': 128, 'regularization': 0.005771448247772546}. Best is trial 56 with value: 1154.2830688294096.
# [I 2024-11-27 09:37:36,386] Trial 57 finished with value: 4332.828051283399 and parameters: {'d_model': 64, 'num_heads': 4, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.3202382951597351, 'learning_rate': 0.0005047706532673925, 'batch_size': 128, 'regularization': 0.0063353802179979225}. Best is trial 56 with value: 1154.2830688294096.
# [I 2024-11-27 09:42:10,529] Trial 58 finished with value: 2557.6360355941706 and parameters: {'d_model': 64, 'num_heads': 4, 'num_encoder_layers': 2, 'dim_feedforward': 128, 'dropout_rate': 0.023104217457474627, 'learning_rate': 0.0002702230660027663, 'batch_size': 128, 'regularization': 0.005762262202813136}. Best is trial 56 with value: 1154.2830688294096.
# [I 2024-11-27 09:50:52,685] Trial 59 finished with value: 3036.6513310590667 and parameters: {'d_model': 64, 'num_heads': 4, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.08088953639328639, 'learning_rate': 0.00020322072474430466, 'batch_size': 128, 'regularization': 0.0031363834776619356}. Best is trial 56 with value: 1154.2830688294096.
# [I 2024-11-27 10:02:23,526] Trial 60 finished with value: 1785.5057723383197 and parameters: {'d_model': 64, 'num_heads': 4, 'num_encoder_layers': 4, 'dim_feedforward': 128, 'dropout_rate': 0.0418923423024396, 'learning_rate': 0.00016771690456081578, 'batch_size': 128, 'regularization': 0.007620797999450511}. Best is trial 56 with value: 1154.2830688294096.
# [I 2024-11-27 10:12:17,511] Trial 61 finished with value: 1193.9696825879928 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.018479384225619094, 'learning_rate': 0.00012511411158847732, 'batch_size': 32, 'regularization': 0.004470865787844028}. Best is trial 56 with value: 1154.2830688294096.
# [I 2024-11-27 10:21:53,073] Trial 62 finished with value: 1232.4550675419237 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.024093645127235292, 'learning_rate': 0.00011656528708985991, 'batch_size': 32, 'regularization': 0.0037600284327518447}. Best is trial 56 with value: 1154.2830688294096.
# [I 2024-11-27 10:49:42,351] Trial 63 finished with value: 1946.5674661998435 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.05530969023258376, 'learning_rate': 0.00012666264102870016, 'batch_size': 128, 'regularization': 0.003503478638000541}. Best is trial 56 with value: 1154.2830688294096.
# [I 2024-11-27 10:56:26,611] Trial 64 finished with value: 1056.4765760025457 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.018234772715573534, 'learning_rate': 0.0002997481946450469, 'batch_size': 32, 'regularization': 0.00022045879878739981}. Best is trial 64 with value: 1056.4765760025457.
# [I 2024-11-27 11:02:46,384] Trial 65 finished with value: 904.8936256670987 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.01840289426376976, 'learning_rate': 0.00040517230292651214, 'batch_size': 32, 'regularization': 0.000359752809885893}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 11:05:12,572] Trial 66 finished with value: 5639.957348742292 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.17441327166799198, 'learning_rate': 0.0004804886497829413, 'batch_size': 32, 'regularization': 0.00016368135114362757}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 11:11:24,483] Trial 67 finished with value: 1271.25500214581 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.06683511209312078, 'learning_rate': 0.0003928178531134364, 'batch_size': 32, 'regularization': 0.0001837115779505656}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 11:17:52,216] Trial 68 finished with value: 1170.232161129893 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.03702915336036874, 'learning_rate': 0.0006605542146931136, 'batch_size': 128, 'regularization': 0.00032343239710504884}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 11:22:36,730] Trial 69 finished with value: 2572.659534403027 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.09683129578753943, 'learning_rate': 0.0006878562871970319, 'batch_size': 128, 'regularization': 0.000362813974363756}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 11:26:36,162] Trial 70 finished with value: 3684.164034765041 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.137268451106895, 'learning_rate': 0.0008468243801523586, 'batch_size': 128, 'regularization': 0.00020593293948424998}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 11:38:36,871] Trial 71 finished with value: 1006.6373888594509 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.018508394417622795, 'learning_rate': 0.0002913929493632265, 'batch_size': 128, 'regularization': 0.00023466524677099137}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 11:49:53,413] Trial 72 finished with value: 1310.8922137387308 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.039037141972994446, 'learning_rate': 0.0002606867797381324, 'batch_size': 128, 'regularization': 0.0003623158044350566}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 12:00:42,873] Trial 73 finished with value: 1016.71561421621 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.019028559813873292, 'learning_rate': 0.00030579697527600405, 'batch_size': 128, 'regularization': 0.0002313467456898209}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 12:10:48,782] Trial 74 finished with value: 1433.101798794551 and parameters: {'d_model': 64, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.04128891491986447, 'learning_rate': 0.00030531917781635037, 'batch_size': 128, 'regularization': 0.0001291544343023845}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 12:19:50,257] Trial 75 finished with value: 1007.6801228658679 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.015563425091374409, 'learning_rate': 0.0005455022749670339, 'batch_size': 128, 'regularization': 0.00021840600580733433}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 12:22:30,955] Trial 76 finished with value: 19819.746841134154 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 2, 'dim_feedforward': 256, 'dropout_rate': 0.22515975510094507, 'learning_rate': 0.0005482891663702022, 'batch_size': 128, 'regularization': 0.00024535453187171256}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 12:27:03,888] Trial 77 finished with value: 1166.0918652088296 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 4, 'dim_feedforward': 256, 'dropout_rate': 0.015840043273417925, 'learning_rate': 0.0012344515681055794, 'batch_size': 128, 'regularization': 0.000469772201827179}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 12:35:45,589] Trial 78 finished with value: 1139.8900518716719 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.05512911653170785, 'learning_rate': 0.0010650235562260086, 'batch_size': 128, 'regularization': 7.097180021599643e-05}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 12:43:54,896] Trial 79 finished with value: 2245.6126510095523 and parameters: {'d_model': 32, 'num_heads': 4, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.09049532831947388, 'learning_rate': 0.00041336724051980995, 'batch_size': 128, 'regularization': 4.668581161629683e-05}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 12:49:23,012] Trial 80 finished with value: 1658.3101797517284 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.07287558173870926, 'learning_rate': 0.0017823037064665335, 'batch_size': 128, 'regularization': 9.47259182760154e-05}. Best is trial 65 with value: 904.8936256670987.
# [I 2024-11-27 12:57:39,951] Trial 81 finished with value: 900.8777202155736 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.012245047357927296, 'learning_rate': 0.0010761902255406576, 'batch_size': 128, 'regularization': 1.963884476618992e-05}. Best is trial 81 with value: 900.8777202155736.
# [I 2024-11-27 13:00:09,158] Trial 82 finished with value: 96347.82700392377 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.054314599406482686, 'learning_rate': 0.002808865427847223, 'batch_size': 128, 'regularization': 1.586751061639991e-05}. Best is trial 81 with value: 900.8777202155736.
# [I 2024-11-27 13:07:16,354] Trial 83 finished with value: 979.2467642243846 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.01473783377157621, 'learning_rate': 0.0011008349568034125, 'batch_size': 128, 'regularization': 3.1800440243816303e-05}. Best is trial 81 with value: 900.8777202155736.
# [I 2024-11-27 13:16:33,998] Trial 84 finished with value: 1002.3962209841239 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.032968257456264416, 'learning_rate': 0.0010972503433241923, 'batch_size': 128, 'regularization': 2.7869195669332178e-05}. Best is trial 81 with value: 900.8777202155736.
# [I 2024-11-27 13:23:12,440] Trial 85 finished with value: 1342.4935954140976 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.06231991364203903, 'learning_rate': 0.0011573621632265006, 'batch_size': 128, 'regularization': 2.717753590166907e-05}. Best is trial 81 with value: 900.8777202155736.
# [I 2024-11-27 13:32:30,927] Trial 86 finished with value: 973.14310618402 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.0312438609307173, 'learning_rate': 0.0008071710934127488, 'batch_size': 128, 'regularization': 3.051996458092955e-05}. Best is trial 81 with value: 900.8777202155736.
# [I 2024-11-27 13:41:23,835] Trial 87 finished with value: 1056.2575223777326 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.03470167828633014, 'learning_rate': 0.0008342929417205518, 'batch_size': 128, 'regularization': 2.917279725885564e-05}. Best is trial 81 with value: 900.8777202155736.
# [I 2024-11-27 13:50:48,134] Trial 88 finished with value: 985.7193412837782 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.03308605605348342, 'learning_rate': 0.0008322724302052087, 'batch_size': 128, 'regularization': 3.094096607931305e-05}. Best is trial 81 with value: 900.8777202155736.
# [I 2024-11-27 13:54:33,072] Trial 89 finished with value: 2702.696203668021 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.11643652430041232, 'learning_rate': 0.0021035586266787134, 'batch_size': 128, 'regularization': 4.066286277464356e-05}. Best is trial 81 with value: 900.8777202155736.
# [I 2024-11-27 14:02:18,872] Trial 90 finished with value: 2630.9221833689508 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.26707611812350485, 'learning_rate': 0.0007829829659837379, 'batch_size': 128, 'regularization': 1.8947385612386704e-05}. Best is trial 81 with value: 900.8777202155736.
# [I 2024-11-27 14:07:36,489] Trial 91 finished with value: 1198.0215962271698 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.035480090375398926, 'learning_rate': 0.001463396049990418, 'batch_size': 128, 'regularization': 2.884261626877937e-05}. Best is trial 81 with value: 900.8777202155736.
# [I 2024-11-27 14:16:04,963] Trial 92 finished with value: 923.5264138077763 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.013073740268848217, 'learning_rate': 0.0009829191446225091, 'batch_size': 128, 'regularization': 3.043910934736969e-05}. Best is trial 81 with value: 900.8777202155736.
# [I 2024-11-27 14:25:48,580] Trial 93 finished with value: 876.4179974885265 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.012122943820592716, 'learning_rate': 0.0009945999112164741, 'batch_size': 128, 'regularization': 1.0244940906139135e-05}. Best is trial 93 with value: 876.4179974885265.
# [I 2024-11-27 14:37:36,324] Trial 94 finished with value: 957.5072914659531 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.013707112503975284, 'learning_rate': 0.0005871956751402851, 'batch_size': 128, 'regularization': 1.0111846209167293e-05}. Best is trial 93 with value: 876.4179974885265.
# [I 2024-11-27 14:45:22,194] Trial 95 finished with value: 1131.301657911908 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.045703333284872104, 'learning_rate': 0.0009899082235332469, 'batch_size': 128, 'regularization': 1.0286140896489848e-05}. Best is trial 93 with value: 876.4179974885265.
# [I 2024-11-27 14:50:36,148] Trial 96 finished with value: 1115.3277544098585 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.011749881874681511, 'learning_rate': 0.0024628551022289574, 'batch_size': 128, 'regularization': 1.206217000543626e-05}. Best is trial 93 with value: 876.4179974885265.
# [I 2024-11-27 14:57:37,187] Trial 97 finished with value: 1005.3673672298323 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.03322902737467944, 'learning_rate': 0.0013991975793280487, 'batch_size': 128, 'regularization': 2.075280622279861e-05}. Best is trial 93 with value: 876.4179974885265.
# [I 2024-11-27 15:04:06,083] Trial 98 finished with value: 1072.2146215966286 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.030599356306436336, 'learning_rate': 0.0012885616152811072, 'batch_size': 128, 'regularization': 2.3182694425831124e-05}. Best is trial 93 with value: 876.4179974885265.
# [I 2024-11-27 15:09:39,045] Trial 99 finished with value: 1336.607364397947 and parameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.06911799559495832, 'learning_rate': 0.001627606878834677, 'batch_size': 128, 'regularization': 3.595542766948609e-05}. Best is trial 93 with value: 876.4179974885265.

# %%
# Get the best hyperparameters
best_params = study.best_params
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'d_model': 32, 'num_heads': 8, 'num_encoder_layers': 6, 'dim_feedforward': 256, 'dropout_rate': 0.012122943820592716, 'learning_rate': 0.0009945999112164741, 'batch_size': 128, 'regularization': 1.0244940906139135e-05}

# %%
# Train the final model with the best hyperparameters
final_val_loss, best_model = train_eval(train_dataset, val_dataset,
                                        d_model=best_params['d_model'],
                                        num_heads=best_params['num_heads'],
                                        num_encoder_layers=best_params['num_encoder_layers'],
                                        dim_feedforward=best_params['dim_feedforward'],
                                        dropout_rate=best_params['dropout_rate'],
                                        learning_rate=best_params['learning_rate'],
                                        batch_size=best_params['batch_size'],
                                        regularization=best_params['regularization'],
                                        num_epochs=1000)

# %%
torch.save(best_model.state_dict(), '..\models\\transformer.pth')

# %%
# convert test data to torch tensors
X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).to(device)

# set model to evaluation mode
best_model.eval()

# initialize test loss
test_loss = 0

criterion = nn.MSELoss()

# no need to calculate gradients during testing
with torch.no_grad():
    # forward pass
    test_outputs = best_model(X_test_tensor)
    
    # calculate loss
    test_loss = criterion(test_outputs, y_test_tensor).item()

# print test loss
print(f"Test Loss: {test_loss:.4f}")
# Out:
# Test Loss: 890.1572

# %%
# Move predictions and ground truth to CPU for visualization
pred = test_outputs[0].cpu().numpy()  # Shape: (seq_length, 9)
true = y_test_tensor[0].cpu().numpy()      # Shape: (seq_length, 9)

fig, axes = plt.subplots(3, 3, figsize=(15, 10))  # Create subplots for 9 muscles
axes = axes.flatten()

for i in range(9):
    axes[i].plot(perc_stance, true[:, i], label="True")
    axes[i].plot(perc_stance, pred[:, i], label="Predicted", linestyle='dashed')
    axes[i].set_title(muscle_dict[i])
    axes[i].set_xlabel("Percent Normalized Stance (%)")
    axes[i].set_ylabel("Muscle Force (N)")
    axes[i].legend()

plt.tight_layout()
plt.show()
