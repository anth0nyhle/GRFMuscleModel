# %%
# import opensim as osim
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from OA_utils.data_utils import *

# %%
data_dir = "C:\\Users\\bakel\\Desktop\\GRFMuscleModel\\Old_Young_Walking_Data\\"
# load the data
train_data = np.load(data_dir + 'mixed_train_data.npz')
val_data = np.load(data_dir + 'mixed_val_data.npz')
test_data = np.load(data_dir + 'mixed_test_data.npz')

grf_labels = ['GRF_x', 'GRF_y', 'GRF_z']
muscle_labels = ['tibpost', 'tibant', 'edl', 'ehl', 'fdl', 'fhl', 'perbrev', 'perlong', 'achilles']

grf_dict = {0: 'GRF_x', 1: 'GRF_y', 2: 'GRF_z'}
muscle_dict = {0: 'tibpost', 1: 'tibant', 2: 'edl', 3: 'ehl', 4: 'fdl', 5: 'fhl', 6: 'perbrev', 7: 'perlong', 8: 'achilles'}

# %%
X_train = train_data['X_train']
y_train = train_data['y_train']
X_val = val_data['X_val']
y_val = val_data['y_val']
X_test = test_data['X_test']
y_test = test_data['y_test']

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (1225, 100, 3)
# y_train shape: (1225, 100, 9)
# X_val shape: (153, 100, 3)
# y_val shape: (153, 100, 9)
# X_test shape: (154, 100, 3)
# y_test shape: (154, 100, 9)

# %%
figure = plt.figure(figsize=(10, 10))

num_achilles_segments = len(y_train[:, :, 8])
perc_stance = np.linspace(0, 1, 100)

for i in range(num_achilles_segments):
    plt.plot(perc_stance, y_train[i, :, 8], linewidth=2)

plt.ylabel("Achilles Muscle Force (N)", fontsize=18)
plt.xlabel("Percent Normalized Stance (%)", fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
# Out:
# (array([-500.,    0.,  500., 1000., 1500., 2000., 2500., 3000., 3500.,
#         4000., 4500.]),
#  [Text(0, -500.0, '−500'),
#   Text(0, 0.0, '0'),
#   Text(0, 500.0, '500'),
#   Text(0, 1000.0, '1000'),
#   Text(0, 1500.0, '1500'),
#   Text(0, 2000.0, '2000'),
#   Text(0, 2500.0, '2500'),
#   Text(0, 3000.0, '3000'),
#   Text(0, 3500.0, '3500'),
#   Text(0, 4000.0, '4000'),
#   Text(0, 4500.0, '4500')])

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class CNNLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.0):
        super(CNNLSTMModel, self).__init__()
        
        # define the CNN
        self.cnn = nn.Sequential(
            # nn.Conv1d(in_channels, out_channels, kernel_size, stride=1, padding=0, dilation=1, groups=1, bias=True, padding_mode='zeros', device=None, dtype=None)
            nn.Conv1d(input_size, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=1, padding=1),
            
            nn.Conv1d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=1)
        )
        
        # define the LSTM
        self.lstm = nn.LSTM(128, hidden_size, num_layers, batch_first=True, dropout=dropout)
        
        # define the fully connected layer
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, x):
        x = x.permute(0, 2, 1)  # x shape: (batch_size, grf_dim, seq_len)
        
        # input: (N, C_in, L_in)
        # output: (N, C_out, L_out)
        cnn_out = self.cnn(x)  # cnn_out shape: (batch_size, feature_map_dim, seq_len)

        # permute the dimensions of the output of the CNN
        # (N, C_out, L_out) -> (N, L_out, C_out)
        cnn_out = cnn_out.permute(0, 2, 1)  # cnn_out shape: (batch_size, seq_len, feature_map_dim)
        
        # batch_first=True, so the input and output tensors are provided as (batch, seq, feature)
        # input: (N, L, H_in), H_in = input_size
        # output: (N, L, H_out), H_out = hidden_size
        lstm_out, _ = self.lstm(cnn_out)  # lstm_out shape: (batch_size, seq_len, hidden_size)
        
        # input: (N, *, H_in)
        # output: (N, *, H_out)
        output = self.fc(lstm_out)  # output shape: (batch_size, seq_len, output_size)
        
        return output

# %%
# define device (GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cuda

# %%
from torch.utils.data import TensorDataset, DataLoader

# convert your data to torch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).to(device)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32).to(device)

# create torch datasets
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

# # create dataloaders from datasets
# train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
# val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)

# %%
def train_eval(train_dataset, val_dataset, hidden_size, num_layers, dropout_rate, 
               learning_rate, batch_size, regularization, num_epochs=50):
    # # unpack the hyperparameters
    # hidden_size, num_layers, dropout_rate, learning_rate, batch_size, regularization = params
    # print('------------------------------------------------------------')
    # print(f"hidden_size={hidden_size}, num_layers={num_layers}, dropout_rate={dropout_rate}")
    # print(f"learning_rate={learning_rate}, batch_size={batch_size}, regularization={regularization}")
    # print('------------------------------------------------------------')
    
    # prepare DataLoader with the specified batch size
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size)
    
    # initialize the model
    model = CNNLSTMModel(input_size=3, hidden_size=hidden_size, num_layers=num_layers, output_size=9, dropout=dropout_rate)
    
    # move the model to the device
    model.to(device)    
    
    # initialize the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=regularization)
    
    # early stopping setup
    patience = 10
    best_val_loss = float('inf')
    epochs_without_improvement = 0

    # training loop
    for epoch in range(num_epochs):
        # set the model to train mode
        model.train()
        
        # initialize training loss
        train_loss = 0.0

        # iterate over the training data
        for X_batch, y_batch in train_loader:
            # zero the gradients
            optimizer.zero_grad()
            
            # forward pass
            outputs = model(X_batch)
            
            # calculate the loss
            loss = criterion(outputs, y_batch)
            
            # backward pass and optimization
            loss.backward()
            optimizer.step()
            
            # update training loss
            train_loss += loss.item() * X_batch.size(0)
        
        # average training loss over all samples
        train_loss /= len(train_loader.dataset)
        
        # validation step
        # set the model to evaluation mode
        model.eval()
        
        # initialize validation loss
        val_loss = 0.0
        
        # turn off gradients for validation
        with torch.no_grad():
            # iterate over the validation data
            for X_batch, y_batch in val_loader:
                # forward pass
                outputs = model(X_batch)
                
                # calculate the loss
                loss = criterion(outputs, y_batch)
                
                # update validation loss
                val_loss += loss.item() * X_batch.size(0)

        # average validation loss over all samples
        val_loss /= len(val_loader.dataset)
        
        # # print progress
        # if (epoch + 1) % 10 == 0:
        #     print(f"Epoch [{epoch + 1}/{num_epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        # early stopping check
        if val_loss < best_val_loss:
            # save best validation loss
            best_val_loss = val_loss
            
            # reset epochs without improvement
            epochs_without_improvement = 0
            
            # save the best model
            # torch.save(model.state_dict(), 'best_model.pth')
            best_model_state_dict = model.state_dict()
        else:
            # increment epochs without improvement
            epochs_without_improvement += 1

        # break if patience limit is reached
        if epochs_without_improvement >= patience:
            break

    # load the best model's state for this set of hyperparameters
    # model.load_state_dict(torch.load('best_model.pth'))
    model.load_state_dict(best_model_state_dict)
    
    # return the best validation loss
    return best_val_loss, model

# %%
import optuna

def objective(trial):
    # Sample hyperparameters
    hidden_size = trial.suggest_categorical('hidden_size', [32, 64, 128, 256])
    num_layers = trial.suggest_int('num_layers', 2, 3, step=1)
    dropout_rate = trial.suggest_float('dropout_rate', 0.0, 0.5, log=False)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-2, log=True)
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128])
    regularization = trial.suggest_float('regularization', 1e-5, 1e-2, log=True)

    # Train and evaluate with these hyperparameters
    val_loss, _ = train_eval(train_dataset, val_dataset, hidden_size, num_layers, dropout_rate, 
                             learning_rate, batch_size, regularization, num_epochs=200)
    
    # Return the validation loss (minimize this value)
    return val_loss

# %%
# Define the study
study = optuna.create_study(direction="minimize")  # Minimize validation loss

# Start the optimization
study.optimize(objective, n_trials=100)  # Run 100 trials
# Out:
# [I 2025-11-09 20:40:42,337] A new study created in memory with name: no-name-5b3faf8f-8dcc-490a-9cc5-807f51394e05
# [I 2025-11-09 20:40:49,418] Trial 0 finished with value: 256985.30749591504 and parameters: {'hidden_size': 64, 'num_layers': 3, 'dropout_rate': 0.14409325470680656, 'learning_rate': 0.00016678059156349513, 'batch_size': 128, 'regularization': 0.004011309119785295}. Best is trial 0 with value: 256985.30749591504.
# [I 2025-11-09 20:40:56,300] Trial 1 finished with value: 223865.1580882353 and parameters: {'hidden_size': 32, 'num_layers': 3, 'dropout_rate': 0.013957790711218054, 'learning_rate': 0.0020810898443648336, 'batch_size': 128, 'regularization': 2.4181720919904653e-05}. Best is trial 1 with value: 223865.1580882353.
# [I 2025-11-09 20:41:18,899] Trial 2 finished with value: 57683.93247038399 and parameters: {'hidden_size': 64, 'num_layers': 3, 'dropout_rate': 0.3667476345162706, 'learning_rate': 0.004850313537548615, 'batch_size': 32, 'regularization': 0.0035498736861263695}. Best is trial 2 with value: 57683.93247038399.
# [I 2025-11-09 20:41:25,902] Trial 3 finished with value: 260212.27011846405 and parameters: {'hidden_size': 64, 'num_layers': 3, 'dropout_rate': 0.04149825038627686, 'learning_rate': 9.765963859726552e-05, 'batch_size': 128, 'regularization': 0.0021435133591765445}. Best is trial 2 with value: 57683.93247038399.
# [I 2025-11-09 20:41:46,583] Trial 4 finished with value: 260005.1861723856 and parameters: {'hidden_size': 128, 'num_layers': 2, 'dropout_rate': 0.49566403301959044, 'learning_rate': 1.2558161749833394e-05, 'batch_size': 32, 'regularization': 0.0011083851866874185}. Best is trial 2 with value: 57683.93247038399.
# [I 2025-11-09 20:43:37,962] Trial 5 finished with value: 199336.82424428104 and parameters: {'hidden_size': 256, 'num_layers': 3, 'dropout_rate': 0.3244021535493831, 'learning_rate': 0.00011794451333986906, 'batch_size': 32, 'regularization': 0.007811568754953238}. Best is trial 2 with value: 57683.93247038399.
# [I 2025-11-09 20:43:48,675] Trial 6 finished with value: 253667.50081699347 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout_rate': 0.22751161861816027, 'learning_rate': 0.00012220342737566522, 'batch_size': 64, 'regularization': 0.0009902129465537211}. Best is trial 2 with value: 57683.93247038399.
# [I 2025-11-09 20:44:02,733] Trial 7 finished with value: 255139.95414624183 and parameters: {'hidden_size': 128, 'num_layers': 3, 'dropout_rate': 0.0011974882148691468, 'learning_rate': 4.973333564593612e-05, 'batch_size': 64, 'regularization': 0.005742344188786668}. Best is trial 2 with value: 57683.93247038399.
# [I 2025-11-09 20:44:13,968] Trial 8 finished with value: 214872.27450980392 and parameters: {'hidden_size': 128, 'num_layers': 2, 'dropout_rate': 0.20944251712285644, 'learning_rate': 0.0003313734529879728, 'batch_size': 64, 'regularization': 1.2658842394971294e-05}. Best is trial 2 with value: 57683.93247038399.
# [I 2025-11-09 20:44:20,599] Trial 9 finished with value: 263867.0445261438 and parameters: {'hidden_size': 32, 'num_layers': 3, 'dropout_rate': 0.06960031782624959, 'learning_rate': 5.7734785935933846e-05, 'batch_size': 128, 'regularization': 1.002428886506563e-05}. Best is trial 2 with value: 57683.93247038399.
# [I 2025-11-09 20:45:36,003] Trial 10 finished with value: 21085.20543555964 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3873660753927705, 'learning_rate': 0.004307196630616299, 'batch_size': 32, 'regularization': 0.00014144584387868386}. Best is trial 10 with value: 21085.20543555964.
# [I 2025-11-09 20:46:18,231] Trial 11 finished with value: 33126.09362234477 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3838307239821976, 'learning_rate': 0.0074703448149166605, 'batch_size': 32, 'regularization': 0.00012036547503417452}. Best is trial 10 with value: 21085.20543555964.
# [I 2025-11-09 20:46:50,258] Trial 12 finished with value: 54023.391978145424 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.43886138444654854, 'learning_rate': 0.008609890095630143, 'batch_size': 32, 'regularization': 0.00012500367322587394}. Best is trial 10 with value: 21085.20543555964.
# [I 2025-11-09 20:48:05,579] Trial 13 finished with value: 24385.86150684232 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.33899874003715497, 'learning_rate': 0.0011282151114710111, 'batch_size': 32, 'regularization': 0.00013274417356711073}. Best is trial 10 with value: 21085.20543555964.
# [I 2025-11-09 20:49:20,812] Trial 14 finished with value: 21497.87326388889 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.27886341895885414, 'learning_rate': 0.0011844653673824322, 'batch_size': 32, 'regularization': 0.00023800338729665187}. Best is trial 10 with value: 21085.20543555964.
# [I 2025-11-09 20:50:36,064] Trial 15 finished with value: 26108.215316074347 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.281837144826935, 'learning_rate': 0.0010448694745323886, 'batch_size': 32, 'regularization': 0.00037886867029547514}. Best is trial 10 with value: 21085.20543555964.
# [I 2025-11-09 20:51:51,596] Trial 16 finished with value: 78693.95567810457 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.16779957509870327, 'learning_rate': 0.0005402019653923924, 'batch_size': 32, 'regularization': 4.7113142673820506e-05}. Best is trial 10 with value: 21085.20543555964.
# [I 2025-11-09 20:52:57,379] Trial 17 finished with value: 53513.08172487745 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.42397554274217325, 'learning_rate': 0.0031592582910399893, 'batch_size': 32, 'regularization': 0.0003390778832389716}. Best is trial 10 with value: 21085.20543555964.
# [I 2025-11-09 20:54:12,557] Trial 18 finished with value: 13329.807585273693 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.2836950635695668, 'learning_rate': 0.001530879372309908, 'batch_size': 32, 'regularization': 7.081541808417605e-05}. Best is trial 18 with value: 13329.807585273693.
# [I 2025-11-09 20:54:23,070] Trial 19 finished with value: 181326.99111519608 and parameters: {'hidden_size': 32, 'num_layers': 2, 'dropout_rate': 0.4927190812994912, 'learning_rate': 0.002611334870467518, 'batch_size': 64, 'regularization': 4.4937712370703144e-05}. Best is trial 18 with value: 13329.807585273693.
# [I 2025-11-09 20:55:38,275] Trial 20 finished with value: 116049.8678513072 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.2795982352113609, 'learning_rate': 0.0003644114300164528, 'batch_size': 32, 'regularization': 5.5194790530280885e-05}. Best is trial 18 with value: 13329.807585273693.
# [I 2025-11-09 20:56:53,380] Trial 21 finished with value: 23456.56018944036 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.29793983987081957, 'learning_rate': 0.0011230305363835408, 'batch_size': 32, 'regularization': 0.00019258229179624811}. Best is trial 18 with value: 13329.807585273693.
# [I 2025-11-09 20:58:08,639] Trial 22 finished with value: 11667.951146343954 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.2423412675494591, 'learning_rate': 0.00166817408824309, 'batch_size': 32, 'regularization': 0.0004557724654864748}. Best is trial 22 with value: 11667.951146343954.
# [I 2025-11-09 20:59:24,663] Trial 23 finished with value: 53030.90701593137 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.17623165646905686, 'learning_rate': 0.004411353459921229, 'batch_size': 32, 'regularization': 0.00048059582810225387}. Best is trial 22 with value: 11667.951146343954.
# [I 2025-11-09 21:00:43,902] Trial 24 finished with value: 28011.58477583742 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.11815748032775375, 'learning_rate': 0.0019122534652047565, 'batch_size': 32, 'regularization': 0.0006888030164519816}. Best is trial 22 with value: 11667.951146343954.
# [I 2025-11-09 21:02:02,075] Trial 25 finished with value: 65664.56505310457 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.24968977310841006, 'learning_rate': 0.0006204665020027376, 'batch_size': 32, 'regularization': 7.456366321550148e-05}. Best is trial 22 with value: 11667.951146343954.
# [I 2025-11-09 21:02:09,394] Trial 26 finished with value: 173504.5744485294 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4104800269089196, 'learning_rate': 0.00479274751181639, 'batch_size': 32, 'regularization': 2.2284781703712565e-05}. Best is trial 22 with value: 11667.951146343954.
# [I 2025-11-09 21:02:29,009] Trial 27 finished with value: 151395.35763888888 and parameters: {'hidden_size': 32, 'num_layers': 2, 'dropout_rate': 0.3352695185926873, 'learning_rate': 0.001962640738249496, 'batch_size': 32, 'regularization': 8.31577064584297e-05}. Best is trial 22 with value: 11667.951146343954.
# [I 2025-11-09 21:02:40,682] Trial 28 finished with value: 172007.37408088235 and parameters: {'hidden_size': 128, 'num_layers': 2, 'dropout_rate': 0.222266828670239, 'learning_rate': 0.0007410975152219026, 'batch_size': 64, 'regularization': 0.0015971650555822521}. Best is trial 22 with value: 11667.951146343954.
# [I 2025-11-09 21:02:46,630] Trial 29 finished with value: 253616.83496732026 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout_rate': 0.12377752732259004, 'learning_rate': 0.0002388411778763801, 'batch_size': 128, 'regularization': 0.00022532538420118767}. Best is trial 22 with value: 11667.951146343954.
# [I 2025-11-09 21:02:58,951] Trial 30 finished with value: 96292.94132965687 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4592929342711238, 'learning_rate': 0.009517976120690858, 'batch_size': 128, 'regularization': 0.0006613348274211922}. Best is trial 22 with value: 11667.951146343954.
# [I 2025-11-09 21:04:16,725] Trial 31 finished with value: 19882.53237336601 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.24995979265881457, 'learning_rate': 0.001253591383995181, 'batch_size': 32, 'regularization': 0.00022766654572268954}. Best is trial 22 with value: 11667.951146343954.
# [I 2025-11-09 21:05:34,677] Trial 32 finished with value: 10741.569272109886 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.18607251874735417, 'learning_rate': 0.0017280250682630916, 'batch_size': 32, 'regularization': 3.0336355298650363e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:06:49,268] Trial 33 finished with value: 11400.110881331699 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.19292043468851108, 'learning_rate': 0.0016100095412954066, 'batch_size': 32, 'regularization': 1.8252423698683578e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:08:33,154] Trial 34 finished with value: 27375.42916411356 and parameters: {'hidden_size': 256, 'num_layers': 3, 'dropout_rate': 0.19232654414506836, 'learning_rate': 0.00186293719085752, 'batch_size': 32, 'regularization': 2.2445654081790825e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:08:38,937] Trial 35 finished with value: 165477.44372957517 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout_rate': 0.09571076020633212, 'learning_rate': 0.0033804253732746597, 'batch_size': 128, 'regularization': 2.9861183032511315e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:08:57,774] Trial 36 finished with value: 224438.59293300653 and parameters: {'hidden_size': 32, 'num_layers': 2, 'dropout_rate': 0.14829873469979982, 'learning_rate': 0.0005194928930881676, 'batch_size': 32, 'regularization': 1.501411719447337e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:10:41,312] Trial 37 finished with value: 53442.2406811683 and parameters: {'hidden_size': 256, 'num_layers': 3, 'dropout_rate': 0.18917110872981746, 'learning_rate': 0.0015545755620825204, 'batch_size': 32, 'regularization': 3.454347372466956e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:11:00,105] Trial 38 finished with value: 168082.6045751634 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout_rate': 0.30829300910956126, 'learning_rate': 0.0007852852862195338, 'batch_size': 32, 'regularization': 1.668080623287029e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:11:11,355] Trial 39 finished with value: 65597.52297794117 and parameters: {'hidden_size': 128, 'num_layers': 2, 'dropout_rate': 0.22747984020488796, 'learning_rate': 0.0027592660265888256, 'batch_size': 64, 'regularization': 7.807375505956112e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:11:43,874] Trial 40 finished with value: 229489.99601715687 and parameters: {'hidden_size': 256, 'num_layers': 3, 'dropout_rate': 0.1491499809243737, 'learning_rate': 0.0002151617629339841, 'batch_size': 128, 'regularization': 3.4807078941286214e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:12:57,458] Trial 41 finished with value: 255836.12295751635 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.2541455620175682, 'learning_rate': 1.1075108481317614e-05, 'batch_size': 32, 'regularization': 2.1552410769231224e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:14:10,941] Trial 42 finished with value: 15213.41730494281 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.20886034674697265, 'learning_rate': 0.0014219684613208411, 'batch_size': 32, 'regularization': 5.8051622137673454e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:14:32,249] Trial 43 finished with value: 80358.72497957517 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.2033028260230501, 'learning_rate': 0.006446629927294917, 'batch_size': 32, 'regularization': 5.9201122166501265e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:15:49,233] Trial 44 finished with value: 38973.803538602944 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.254259894109175, 'learning_rate': 0.0008668271751017798, 'batch_size': 32, 'regularization': 1.0578141412217678e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:16:09,294] Trial 45 finished with value: 162156.08925653595 and parameters: {'hidden_size': 128, 'num_layers': 2, 'dropout_rate': 0.042804698411797376, 'learning_rate': 0.0004266539400818021, 'batch_size': 32, 'regularization': 9.9448994048544e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:17:25,680] Trial 46 finished with value: 251067.2651143791 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.17092120419954432, 'learning_rate': 1.8138997070999405e-05, 'batch_size': 32, 'regularization': 0.003397686340051543}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:18:41,674] Trial 47 finished with value: 13829.883348651962 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.35601465371687574, 'learning_rate': 0.0014714538375361337, 'batch_size': 32, 'regularization': 1.7173120479598266e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:18:52,415] Trial 48 finished with value: 184200.8082107843 and parameters: {'hidden_size': 32, 'num_layers': 2, 'dropout_rate': 0.3721802012494604, 'learning_rate': 0.0024540976570580826, 'batch_size': 64, 'regularization': 1.6709689508176492e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:19:52,464] Trial 49 finished with value: 20481.347592422386 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.31001762786788384, 'learning_rate': 0.003625919792039971, 'batch_size': 32, 'regularization': 2.8053087534100245e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:20:14,230] Trial 50 finished with value: 55049.481285743466 and parameters: {'hidden_size': 64, 'num_layers': 3, 'dropout_rate': 0.3278522451544791, 'learning_rate': 0.005570150924143526, 'batch_size': 32, 'regularization': 1.2548859940331101e-05}. Best is trial 32 with value: 10741.569272109886.
# [I 2025-11-09 21:21:30,240] Trial 51 finished with value: 9996.638237847223 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.35798860077828865, 'learning_rate': 0.0017600414247411352, 'batch_size': 32, 'regularization': 3.776848282004578e-05}. Best is trial 51 with value: 9996.638237847223.
# [I 2025-11-09 21:22:46,357] Trial 52 finished with value: 11951.942357281454 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.35280555772583555, 'learning_rate': 0.001609524272157305, 'batch_size': 32, 'regularization': 4.1416084473944676e-05}. Best is trial 51 with value: 9996.638237847223.
# [I 2025-11-09 21:24:02,312] Trial 53 finished with value: 10651.504027522467 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3555080658484589, 'learning_rate': 0.0017649845106366452, 'batch_size': 32, 'regularization': 4.094512146423416e-05}. Best is trial 51 with value: 9996.638237847223.
# [I 2025-11-09 21:25:18,218] Trial 54 finished with value: 7530.179489634395 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.399125731732521, 'learning_rate': 0.0023825620043701036, 'batch_size': 32, 'regularization': 3.930464315143356e-05}. Best is trial 54 with value: 7530.179489634395.
# [I 2025-11-09 21:26:36,085] Trial 55 finished with value: 8463.175366370506 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3877327343687156, 'learning_rate': 0.002314735122430927, 'batch_size': 32, 'regularization': 0.0001676200846578558}. Best is trial 54 with value: 7530.179489634395.
# [I 2025-11-09 21:27:51,125] Trial 56 finished with value: 7369.621661815768 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.40224948857499565, 'learning_rate': 0.0024787428488531305, 'batch_size': 32, 'regularization': 3.875126342377023e-05}. Best is trial 56 with value: 7369.621661815768.
# [I 2025-11-09 21:29:04,728] Trial 57 finished with value: 7612.938495710784 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.40332321268099297, 'learning_rate': 0.002204149251803558, 'batch_size': 32, 'regularization': 4.0572350655991945e-05}. Best is trial 56 with value: 7369.621661815768.
# [I 2025-11-09 21:30:17,268] Trial 58 finished with value: 12899.51918019812 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.40025314998009, 'learning_rate': 0.0024167420558942436, 'batch_size': 32, 'regularization': 0.00016388819222804213}. Best is trial 56 with value: 7369.621661815768.
# [I 2025-11-09 21:30:28,052] Trial 59 finished with value: 51582.53507965686 and parameters: {'hidden_size': 128, 'num_layers': 2, 'dropout_rate': 0.4517134545720042, 'learning_rate': 0.003539280544661052, 'batch_size': 64, 'regularization': 4.1552797496471345e-05}. Best is trial 56 with value: 7369.621661815768.
# [I 2025-11-09 21:30:33,387] Trial 60 finished with value: 169679.48784722222 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.42635485626253167, 'learning_rate': 0.006903543844965321, 'batch_size': 128, 'regularization': 9.909152011232172e-05}. Best is trial 56 with value: 7369.621661815768.
# [I 2025-11-09 21:31:43,336] Trial 61 finished with value: 33667.803053513075 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.39170435982757146, 'learning_rate': 0.000930282478485167, 'batch_size': 32, 'regularization': 3.064459435496457e-05}. Best is trial 56 with value: 7369.621661815768.
# [I 2025-11-09 21:32:53,444] Trial 62 finished with value: 8147.638001685049 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.477646767930858, 'learning_rate': 0.0020603741513170563, 'batch_size': 32, 'regularization': 5.2266134112611056e-05}. Best is trial 56 with value: 7369.621661815768.
# [I 2025-11-09 21:34:03,537] Trial 63 finished with value: 6591.549160028595 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4705812301584939, 'learning_rate': 0.0028376153426699705, 'batch_size': 32, 'regularization': 6.042414147385746e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:34:14,728] Trial 64 finished with value: 166761.89317810457 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.49000911335597663, 'learning_rate': 0.004106785933672867, 'batch_size': 32, 'regularization': 5.576383374295646e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:35:24,658] Trial 65 finished with value: 8683.167068780638 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4744181508203123, 'learning_rate': 0.0024227104360784496, 'batch_size': 32, 'regularization': 4.9287156395666075e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:36:21,264] Trial 66 finished with value: 28277.463324652777 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4645644386661251, 'learning_rate': 0.002312405079443358, 'batch_size': 32, 'regularization': 0.00010581975953703999}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:36:39,055] Trial 67 finished with value: 73392.11488970589 and parameters: {'hidden_size': 32, 'num_layers': 2, 'dropout_rate': 0.4729778547932136, 'learning_rate': 0.0054112179216445205, 'batch_size': 32, 'regularization': 0.00014830612494900463}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:37:52,223] Trial 68 finished with value: 22354.273194955065 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.44110384308923717, 'learning_rate': 0.0029686495685245853, 'batch_size': 32, 'regularization': 6.458720726319593e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:39:09,747] Trial 69 finished with value: 8197.999802134396 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.417278722340508, 'learning_rate': 0.002200358478380633, 'batch_size': 32, 'regularization': 5.1173171557391875e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:40:25,568] Trial 70 finished with value: 18639.10235396242 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4217355306916324, 'learning_rate': 0.0012314120089808142, 'batch_size': 32, 'regularization': 7.955078999035984e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:41:43,063] Trial 71 finished with value: 8891.7901220384 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.48079944827945037, 'learning_rate': 0.0021725585070644093, 'batch_size': 32, 'regularization': 4.6242195661329636e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:42:58,518] Trial 72 finished with value: 9133.159505208334 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4418130071021793, 'learning_rate': 0.002836528942850828, 'batch_size': 32, 'regularization': 5.087132673663241e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:44:02,329] Trial 73 finished with value: 57011.68185763889 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.41028286414351134, 'learning_rate': 0.0037857811616356435, 'batch_size': 32, 'regularization': 2.7215047731902194e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:45:00,195] Trial 74 finished with value: 53590.69904003268 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.378213550227289, 'learning_rate': 0.004398287669287824, 'batch_size': 32, 'regularization': 0.00011605393212732995}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:46:16,608] Trial 75 finished with value: 223233.1796364379 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4314257958223929, 'learning_rate': 6.64851189229036e-05, 'batch_size': 32, 'regularization': 0.0002736613508493325}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:46:36,175] Trial 76 finished with value: 52087.5345435049 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout_rate': 0.49950966839010996, 'learning_rate': 0.0031462061386914454, 'batch_size': 32, 'regularization': 6.659837720856057e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:46:59,621] Trial 77 finished with value: 83864.43949142157 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.451448263691672, 'learning_rate': 0.0022255375316093313, 'batch_size': 128, 'regularization': 8.484541553545292e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:47:29,364] Trial 78 finished with value: 48895.2652930964 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.40904881158257167, 'learning_rate': 0.008199775728063628, 'batch_size': 64, 'regularization': 0.009295251520578222}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:47:50,095] Trial 79 finished with value: 79221.09043096405 and parameters: {'hidden_size': 128, 'num_layers': 2, 'dropout_rate': 0.46911328085999593, 'learning_rate': 0.001069265034305633, 'batch_size': 32, 'regularization': 0.00018102018509169208}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:48:57,391] Trial 80 finished with value: 22412.04438572304 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.39204290671476716, 'learning_rate': 0.0058865295438409624, 'batch_size': 32, 'regularization': 5.0778567383473525e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:50:14,225] Trial 81 finished with value: 8098.042777267156 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4816516522766036, 'learning_rate': 0.0020806113020239263, 'batch_size': 32, 'regularization': 4.7052706443571396e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:51:21,631] Trial 82 finished with value: 10082.98184104371 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4764015247003703, 'learning_rate': 0.0026842438563879703, 'batch_size': 32, 'regularization': 2.3924741521199658e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:52:37,181] Trial 83 finished with value: 16548.171185661766 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4547770240066118, 'learning_rate': 0.001319521453007893, 'batch_size': 32, 'regularization': 3.558291709752871e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:52:45,263] Trial 84 finished with value: 169426.45894607843 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.41820356588795066, 'learning_rate': 0.004931647195662554, 'batch_size': 32, 'regularization': 6.960487297294246e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:53:59,389] Trial 85 finished with value: 8346.032788245506 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.48457967841813265, 'learning_rate': 0.0022295950043936135, 'batch_size': 32, 'regularization': 4.9029296352759445e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:54:18,427] Trial 86 finished with value: 148907.90788398692 and parameters: {'hidden_size': 32, 'num_layers': 2, 'dropout_rate': 0.4340140876659801, 'learning_rate': 0.0020294743450224276, 'batch_size': 32, 'regularization': 9.034675583563391e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:55:33,137] Trial 87 finished with value: 8243.05322584763 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4903779096835429, 'learning_rate': 0.0020859818462567186, 'batch_size': 32, 'regularization': 2.5352557663853173e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:56:14,784] Trial 88 finished with value: 49392.11864276961 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.48126088771603637, 'learning_rate': 0.003321641147755539, 'batch_size': 32, 'regularization': 3.476808404991436e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:57:31,592] Trial 89 finished with value: 29572.09849877451 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.48999787407275086, 'learning_rate': 0.0009830222432142901, 'batch_size': 32, 'regularization': 2.5771763381307773e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:57:37,457] Trial 90 finished with value: 235930.19260620914 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout_rate': 0.44679429148471883, 'learning_rate': 0.0006902178856895425, 'batch_size': 128, 'regularization': 2.2508680642198858e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 21:58:50,059] Trial 91 finished with value: 8176.604619842728 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.45934786593527244, 'learning_rate': 0.0019622885550347547, 'batch_size': 32, 'regularization': 3.074332337635444e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 22:00:04,784] Trial 92 finished with value: 16553.947329452614 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.46022425330898764, 'learning_rate': 0.0013161112990114749, 'batch_size': 32, 'regularization': 4.556711146159481e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 22:01:22,785] Trial 93 finished with value: 6899.099820006128 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.48585264449551485, 'learning_rate': 0.002073623310807748, 'batch_size': 32, 'regularization': 2.0749367071912214e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 22:02:51,898] Trial 94 finished with value: 7751.036451950572 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4663185925141691, 'learning_rate': 0.0020450480836950746, 'batch_size': 32, 'regularization': 2.0254213518707275e-05}. Best is trial 63 with value: 6591.549160028595.
# [I 2025-11-09 22:04:36,442] Trial 95 finished with value: 6450.3159594567 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4389768052305767, 'learning_rate': 0.0028594522510563226, 'batch_size': 32, 'regularization': 1.452211308497396e-05}. Best is trial 95 with value: 6450.3159594567.
# [I 2025-11-09 22:05:44,493] Trial 96 finished with value: 31369.71567350899 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4610700554438851, 'learning_rate': 0.0029023022242121873, 'batch_size': 32, 'regularization': 1.350819720776483e-05}. Best is trial 95 with value: 6450.3159594567.
# [I 2025-11-09 22:06:41,501] Trial 97 finished with value: 39942.67169628268 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.44230672363923434, 'learning_rate': 0.0018236085698324135, 'batch_size': 64, 'regularization': 2.0436668464145242e-05}. Best is trial 95 with value: 6450.3159594567.
# [I 2025-11-09 22:07:06,160] Trial 98 finished with value: 254619.0066380719 and parameters: {'hidden_size': 128, 'num_layers': 2, 'dropout_rate': 0.49929223551348934, 'learning_rate': 2.742952066431479e-05, 'batch_size': 32, 'regularization': 1.9865739680074668e-05}. Best is trial 95 with value: 6450.3159594567.
# [I 2025-11-09 22:09:17,146] Trial 99 finished with value: 22417.52210988562 and parameters: {'hidden_size': 256, 'num_layers': 3, 'dropout_rate': 0.40297234492664763, 'learning_rate': 0.004110008675575289, 'batch_size': 32, 'regularization': 1.0405342578503632e-05}. Best is trial 95 with value: 6450.3159594567.

# %%
# Get the best hyperparameters
best_params = study.best_params
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4389768052305767, 'learning_rate': 0.0028594522510563226, 'batch_size': 32, 'regularization': 1.452211308497396e-05}

# %%
# Train the final model with the best hyperparameters
final_val_loss, best_model = train_eval(train_dataset, val_dataset,
                                        hidden_size=best_params['hidden_size'],
                                        num_layers=best_params['num_layers'],
                                        dropout_rate=best_params['dropout_rate'],
                                        learning_rate=best_params['learning_rate'],
                                        batch_size=best_params['batch_size'],
                                        regularization=best_params['regularization'],
                                        num_epochs=1000)

# %%
torch.save(best_model.state_dict(), '..\models\Mixed_cnn-lstm.pth')

# %%
# convert test data to torch tensors
X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).to(device)

# set model to evaluation mode
best_model.eval()

# initialize test loss
test_loss = 0

criterion = nn.MSELoss()

# no need to calculate gradients during testing
with torch.no_grad():
    # forward pass
    test_outputs = best_model(X_test_tensor)
    
    # calculate loss
    test_loss = criterion(test_outputs, y_test_tensor).item()

# print test loss
print(f"Test Loss: {test_loss:.4f}")
# Out:
# Test Loss: 6982.4893

# %%
# Move predictions and ground truth to CPU for visualization
pred = test_outputs[0].cpu().numpy()  # Shape: (seq_length, 9)
true = y_test_tensor[0].cpu().numpy()      # Shape: (seq_length, 9)

fig, axes = plt.subplots(3, 3, figsize=(15, 10))  # Create subplots for 9 muscles
axes = axes.flatten()

for i in range(9):
    axes[i].plot(perc_stance, true[:, i], label="True")
    axes[i].plot(perc_stance, pred[:, i], label="Predicted", linestyle='dashed')
    axes[i].set_title(muscle_dict[i])
    axes[i].set_xlabel("Percent Normalized Stance (%)")
    axes[i].set_ylabel("Muscle Force (N)")
    axes[i].legend()

plt.tight_layout()
plt.show()
