# %%
# import opensim as osim
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from OA_utils.data_utils import *

# %%
data_dir = "C:\\Users\\bakel\\Desktop\\GRFMuscleModel\\Old_Young_Walking_Data\\"
# load the data
train_data = np.load(data_dir + 'mixed_train_data.npz')
val_data = np.load(data_dir + 'mixed_val_data.npz')
test_data = np.load(data_dir + 'mixed_test_data.npz')

grf_labels = ['GRF_x', 'GRF_y', 'GRF_z']
muscle_labels = ['tibpost', 'tibant', 'edl', 'ehl', 'fdl', 'fhl', 'perbrev', 'perlong', 'achilles']

grf_dict = {0: 'GRF_x', 1: 'GRF_y', 2: 'GRF_z'}
muscle_dict = {0: 'tibpost', 1: 'tibant', 2: 'edl', 3: 'ehl', 4: 'fdl', 5: 'fhl', 6: 'perbrev', 7: 'perlong', 8: 'achilles'}

# %%
X_train = train_data['X_train']
y_train = train_data['y_train']
X_val = val_data['X_val']
y_val = val_data['y_val']
X_test = test_data['X_test']
y_test = test_data['y_test']

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (1153, 100, 3)
# y_train shape: (1153, 100, 9)
# X_val shape: (142, 100, 3)
# y_val shape: (142, 100, 9)
# X_test shape: (116, 100, 3)
# y_test shape: (116, 100, 9)

# %%
figure = plt.figure(figsize=(10, 10))

num_achilles_segments = len(y_train[:, :, 8])
perc_stance = np.linspace(0, 1, 100)

for i in range(num_achilles_segments):
    plt.plot(perc_stance, y_train[i, :, 8], linewidth=2)

plt.ylabel("Achilles Muscle Force (N)", fontsize=18)
plt.xlabel("Percent Normalized Stance (%)", fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
# Out:
# (array([-500.,    0.,  500., 1000., 1500., 2000., 2500., 3000., 3500.,
#         4000., 4500.]),
#  [Text(0, -500.0, '−500'),
#   Text(0, 0.0, '0'),
#   Text(0, 500.0, '500'),
#   Text(0, 1000.0, '1000'),
#   Text(0, 1500.0, '1500'),
#   Text(0, 2000.0, '2000'),
#   Text(0, 2500.0, '2500'),
#   Text(0, 3000.0, '3000'),
#   Text(0, 3500.0, '3500'),
#   Text(0, 4000.0, '4000'),
#   Text(0, 4500.0, '4500')])

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class CNNLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.0):
        super(CNNLSTMModel, self).__init__()
        
        # # define the CNN
        self.cnn = nn.Sequential(
                    # nn.Conv1d(in_channels, out_channels, kernel_size, stride=1, padding=0, dilation=1, groups=1, bias=True, padding_mode='zeros', device=None, dtype=None)
                    nn.Conv1d(input_size, 64, kernel_size=3, stride=1, padding=1),
                    nn.ReLU(),
                    nn.MaxPool1d(kernel_size=2, stride=1, padding=1),
                    
                    nn.Conv1d(64, 128, kernel_size=3, stride=1, padding=1),
                    nn.ReLU(),
                    nn.MaxPool1d(kernel_size=2, stride=1)
                )
        

        # define the LSTM
        self.lstm = nn.LSTM(128, hidden_size, num_layers, batch_first=True, dropout=dropout)
        
        # define the fully connected layer
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, x):
        x = x.permute(0, 2, 1)  # x shape: (batch_size, grf_dim, seq_len)
        
        # input: (N, C_in, L_in)
        # output: (N, C_out, L_out)
        cnn_out = self.cnn(x)  # cnn_out shape: (batch_size, feature_map_dim, seq_len)

        # permute the dimensions of the output of the CNN
        # (N, C_out, L_out) -> (N, L_out, C_out)
        cnn_out = cnn_out.permute(0, 2, 1)  # cnn_out shape: (batch_size, seq_len, feature_map_dim)
        
        # batch_first=True, so the input and output tensors are provided as (batch, seq, feature)
        # input: (N, L, H_in), H_in = input_size
        # output: (N, L, H_out), H_out = hidden_size
        lstm_out, _ = self.lstm(cnn_out)  # lstm_out shape: (batch_size, seq_len, hidden_size)
        
        # input: (N, *, H_in)
        # output: (N, *, H_out)
        output = self.fc(lstm_out)  # output shape: (batch_size, seq_len, output_size)
        
        return output

# %%
# define device (GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cuda

# %%
from torch.utils.data import TensorDataset, DataLoader

# convert your data to torch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).to(device)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32).to(device)

# create torch datasets
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

# # create dataloaders from datasets
# train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
# val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Try to overfit on small subset of training data to make sure model has representational power.

# %%
def test_overfit_CNNLSTM(train_data,  hidden_size=64, 
                 num_layers=2, 
                 epochs=300,
                 lr=1e-3,
                 num_samples=128):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    #take a subset of the data
    data_subset = torch.utils.data.Subset(train_data, range(num_samples))
    subset_loader = DataLoader(data_subset, batch_size=num_samples, shuffle=True)
    #create a small model with no dropout
    model = CNNLSTMModel(input_size=3,
                         hidden_size=hidden_size,
                        num_layers=num_layers,
                        output_size=9,
                        dropout=0.0).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=0.0)
    criterion = nn.MSELoss()
    #train until training data memorized
    for epoch in range(epochs):
        model.train()
        for X, y in subset_loader:
            X, y = X.to(device), y.to(device)
            optimizer.zero_grad()
            pred = model(X)
            loss = criterion(pred, y)
            loss.backward()
            optimizer.step()

        if epoch % 50 == 0:
            print(f"Epoch {epoch} — Loss: {loss.item():.6f}")

    # 4. Final evaluation
    model.eval()
    with torch.no_grad():
        pred = model(X)
        final_loss = criterion(pred, y).item()

    print("\nFinal tiny-set loss:", final_loss)
    return model, pred.detach().cpu(), y.detach().cpu()

# %%
test_overfit_CNNLSTM(train_dataset)
# Out:
# c:\Users\bakel\anaconda3\envs\opensim_scripting\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([128, 100, 9])) that is different to the input size (torch.Size([128, 25, 9])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 test_overfit_CNNLSTM(train_dataset)
#
# Cell In[22], line 25, in test_overfit_CNNLSTM(train_data, hidden_size, num_layers, epochs, lr, num_samples)
#      23 optimizer.zero_grad()
#      24 pred = model(X)
# ---> 25 loss = criterion(pred, y)
#      26 loss.backward()
#      27 optimizer.step()
#
# File c:\Users\bakel\anaconda3\envs\opensim_scripting\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\bakel\anaconda3\envs\opensim_scripting\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\bakel\anaconda3\envs\opensim_scripting\Lib\site-packages\torch\nn\modules\loss.py:608, in MSELoss.forward(self, input, target)
#     607 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 608     return F.mse_loss(input, target, reduction=self.reduction)
#
# File c:\Users\bakel\anaconda3\envs\opensim_scripting\Lib\site-packages\torch\nn\functional.py:3791, in mse_loss(input, target, size_average, reduce, reduction)
#    3788 if size_average is not None or reduce is not None:
#    3789     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3791 expanded_input, expanded_target = torch.broadcast_tensors(input, target)
#    3792 return torch._C._nn.mse_loss(
#    3793     expanded_input, expanded_target, _Reduction.get_enum(reduction)
#    3794 )
#
# File c:\Users\bakel\anaconda3\envs\opensim_scripting\Lib\site-packages\torch\functional.py:76, in broadcast_tensors(*tensors)
#      74 if has_torch_function(tensors):
#      75     return handle_torch_function(broadcast_tensors, tensors, *tensors)
# ---> 76 return _VF.broadcast_tensors(tensors)
#
# RuntimeError: The size of tensor a (25) must match the size of tensor b (100) at non-singleton dimension 1

# %%
def train_eval(train_dataset, val_dataset, hidden_size, num_layers, dropout_rate, 
               learning_rate, batch_size, regularization, num_epochs=50):
    # # unpack the hyperparameters
    # hidden_size, num_layers, dropout_rate, learning_rate, batch_size, regularization = params
    # print('------------------------------------------------------------')
    # print(f"hidden_size={hidden_size}, num_layers={num_layers}, dropout_rate={dropout_rate}")
    # print(f"learning_rate={learning_rate}, batch_size={batch_size}, regularization={regularization}")
    # print('------------------------------------------------------------')
    
    # prepare DataLoader with the specified batch size
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size)
    
    # initialize the model
    model = CNNLSTMModel(input_size=3, hidden_size=hidden_size, num_layers=num_layers, output_size=9, dropout=dropout_rate)
    
    # move the model to the device
    model.to(device)    
    
    # initialize the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=regularization)
    
    # early stopping setup
    patience = 10
    best_val_loss = float('inf')
    epochs_without_improvement = 0

    # training loop
    for epoch in range(num_epochs):
        # set the model to train mode
        model.train()
        
        # initialize training loss
        train_loss = 0.0

        # iterate over the training data
        for X_batch, y_batch in train_loader:
            # zero the gradients
            optimizer.zero_grad()
            
            # forward pass
            outputs = model(X_batch)
            
            # calculate the loss
            loss = criterion(outputs, y_batch)
            
            # backward pass and optimization
            loss.backward()
            optimizer.step()
            
            # update training loss
            train_loss += loss.item() * X_batch.size(0)
        
        # average training loss over all samples
        train_loss /= len(train_loader.dataset)
        
        # validation step
        # set the model to evaluation mode
        model.eval()
        
        # initialize validation loss
        val_loss = 0.0
        
        # turn off gradients for validation
        with torch.no_grad():
            # iterate over the validation data
            for X_batch, y_batch in val_loader:
                # forward pass
                outputs = model(X_batch)
                
                # calculate the loss
                loss = criterion(outputs, y_batch)
                
                # update validation loss
                val_loss += loss.item() * X_batch.size(0)

        # average validation loss over all samples
        val_loss /= len(val_loader.dataset)
        
        # # print progress
        # if (epoch + 1) % 10 == 0:
        #     print(f"Epoch [{epoch + 1}/{num_epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        # early stopping check
        if val_loss < best_val_loss:
            # save best validation loss
            best_val_loss = val_loss
            
            # reset epochs without improvement
            epochs_without_improvement = 0
            
            # save the best model
            # torch.save(model.state_dict(), 'best_model.pth')
            best_model_state_dict = model.state_dict()
        else:
            # increment epochs without improvement
            epochs_without_improvement += 1

        # break if patience limit is reached
        if epochs_without_improvement >= patience:
            break

    # load the best model's state for this set of hyperparameters
    # model.load_state_dict(torch.load('best_model.pth'))
    model.load_state_dict(best_model_state_dict)
    
    # return the best validation loss
    return best_val_loss, model

# %%
import optuna

def objective(trial):
    # Sample hyperparameters
    hidden_size = trial.suggest_categorical("hidden_size", [256])  # fixed
    num_layers = trial.suggest_categorical("num_layers", [2])      # fixed
    dropout_rate = trial.suggest_float(
        "dropout_rate",
        0.25, 0.50
    )
    learning_rate = trial.suggest_float(
        "learning_rate",
        0.0017, 0.0035,
        log=True
    )
    batch_size = 32  # fixed
    regularization = trial.suggest_float(
        "regularization",
        1e-5, 3e-4,
        log=True
    )

    # Train and evaluate with these hyperparameters
    val_loss, _ = train_eval(train_dataset, val_dataset, hidden_size, num_layers, dropout_rate, 
                             learning_rate, batch_size, regularization, num_epochs=200)
    
    # Return the validation loss (minimize this value)
    return val_loss

# %%
# Define the study
study = optuna.create_study(direction="minimize")  # Minimize validation loss

# Start the optimization
study.optimize(objective, n_trials=100)  # Run 100 trials
# Out:
# [I 2025-11-30 18:01:54,323] A new study created in memory with name: no-name-f5d8c1f0-7a4a-4ce9-b08d-e0336c5dc12d
# [I 2025-11-30 18:02:52,583] Trial 0 finished with value: 19005.930925396126 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4206332656437039, 'learning_rate': 0.002737800078841486, 'regularization': 2.4699207748499046e-05}. Best is trial 0 with value: 19005.930925396126.
# [I 2025-11-30 18:04:02,672] Trial 1 finished with value: 8606.17899977993 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.2664172569493043, 'learning_rate': 0.0022785560779606286, 'regularization': 0.00016770476496488646}. Best is trial 1 with value: 8606.17899977993.
# [I 2025-11-30 18:05:12,785] Trial 2 finished with value: 8255.619883362677 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.34408781124696164, 'learning_rate': 0.0020968693002196338, 'regularization': 9.383212808008531e-05}. Best is trial 2 with value: 8255.619883362677.
# [I 2025-11-30 18:06:01,466] Trial 3 finished with value: 21915.334479533452 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.38277123928718937, 'learning_rate': 0.0024266297505069635, 'regularization': 1.9116032708191354e-05}. Best is trial 2 with value: 8255.619883362677.
# [I 2025-11-30 18:07:11,185] Trial 4 finished with value: 8130.299818441901 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.41649629980043534, 'learning_rate': 0.0020497183641204437, 'regularization': 3.03232231559486e-05}. Best is trial 4 with value: 8130.299818441901.
# [I 2025-11-30 18:08:09,467] Trial 5 finished with value: 10790.664310079226 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.48931285160052485, 'learning_rate': 0.0023295277959113347, 'regularization': 5.6105342267584506e-05}. Best is trial 4 with value: 8130.299818441901.
# [I 2025-11-30 18:09:19,697] Trial 6 finished with value: 8237.08681778169 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4093005810474015, 'learning_rate': 0.002644851734053306, 'regularization': 0.00013327977858716502}. Best is trial 4 with value: 8130.299818441901.
# [I 2025-11-30 18:10:30,058] Trial 7 finished with value: 10002.51034330986 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.352714192059168, 'learning_rate': 0.0018117593862848245, 'regularization': 1.2473407083331122e-05}. Best is trial 4 with value: 8130.299818441901.
# [I 2025-11-30 18:11:20,050] Trial 8 finished with value: 13914.409000880281 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3234664300927643, 'learning_rate': 0.0034755303152413553, 'regularization': 3.1956986261726703e-05}. Best is trial 4 with value: 8130.299818441901.
# [I 2025-11-30 18:12:27,229] Trial 9 finished with value: 8761.525156800177 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.44533729406736466, 'learning_rate': 0.002325524695361118, 'regularization': 2.287904726531628e-05}. Best is trial 4 with value: 8130.299818441901.
# [I 2025-11-30 18:13:37,559] Trial 10 finished with value: 10660.237964898768 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.49335426380565706, 'learning_rate': 0.0017104347418182696, 'regularization': 0.0002850767844498809}. Best is trial 4 with value: 8130.299818441901.
# [I 2025-11-30 18:14:29,981] Trial 11 finished with value: 20775.398685079224 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4096791290757363, 'learning_rate': 0.0028227794462465797, 'regularization': 6.408526432622689e-05}. Best is trial 4 with value: 8130.299818441901.
# [I 2025-11-30 18:15:36,569] Trial 12 finished with value: 10889.581027178698 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.44000537947906426, 'learning_rate': 0.001969813428796525, 'regularization': 0.00011424248294902644}. Best is trial 4 with value: 8130.299818441901.
# [I 2025-11-30 18:16:38,164] Trial 13 finished with value: 8358.50419509243 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.38869647498703336, 'learning_rate': 0.002789655177522356, 'regularization': 3.746630136531906e-05}. Best is trial 4 with value: 8130.299818441901.
# [I 2025-11-30 18:17:43,551] Trial 14 finished with value: 45120.42016945423 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.455993734347786, 'learning_rate': 0.003014379142658949, 'regularization': 0.00021842059291872636}. Best is trial 4 with value: 8130.299818441901.
# [I 2025-11-30 18:18:53,753] Trial 15 finished with value: 8622.785032460388 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.2970207495640268, 'learning_rate': 0.0020577509638425324, 'regularization': 9.642889464438058e-05}. Best is trial 4 with value: 8130.299818441901.
# [I 2025-11-30 18:19:44,041] Trial 16 finished with value: 12159.983962367958 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.40599076385012345, 'learning_rate': 0.0026125469016240895, 'regularization': 1.0271353842958988e-05}. Best is trial 4 with value: 8130.299818441901.
# [I 2025-11-30 18:20:49,722] Trial 17 finished with value: 11302.735764194542 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.47023955967851405, 'learning_rate': 0.0019096427091704804, 'regularization': 0.00014106198440777963}. Best is trial 4 with value: 8130.299818441901.
# [I 2025-11-30 18:21:44,575] Trial 18 finished with value: 16933.370075924297 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.35576982546526975, 'learning_rate': 0.003124708383027061, 'regularization': 6.718691396718036e-05}. Best is trial 4 with value: 8130.299818441901.
# [I 2025-11-30 18:22:55,133] Trial 19 finished with value: 7433.276972381162 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4315602294925629, 'learning_rate': 0.0025661344589430423, 'regularization': 4.5550879508136915e-05}. Best is trial 19 with value: 7433.276972381162.
# [I 2025-11-30 18:24:05,983] Trial 20 finished with value: 8412.260907240317 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.42960220252171294, 'learning_rate': 0.0021521600867101935, 'regularization': 4.248264768284225e-05}. Best is trial 19 with value: 7433.276972381162.
# [I 2025-11-30 18:25:16,552] Trial 21 finished with value: 7247.111878301056 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.39879954424632785, 'learning_rate': 0.0025445231792625487, 'regularization': 4.4504711132793825e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:26:22,051] Trial 22 finished with value: 8074.6614079005285 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.38032832240897824, 'learning_rate': 0.0024846633093556477, 'regularization': 4.686092384523049e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:27:33,085] Trial 23 finished with value: 14975.11806778169 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.38368565197614785, 'learning_rate': 0.002538041213137017, 'regularization': 4.6233010847146494e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:28:43,625] Trial 24 finished with value: 25718.464953785213 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.36814135791059993, 'learning_rate': 0.0025231270196921845, 'regularization': 7.570654917590799e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:29:36,941] Trial 25 finished with value: 14635.96181778169 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.32255453518436117, 'learning_rate': 0.003011704414401696, 'regularization': 4.9921559117955146e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:30:41,920] Trial 26 finished with value: 9330.46953400088 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4694235137959527, 'learning_rate': 0.0024143788638222117, 'regularization': 1.4712874686152415e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:31:52,501] Trial 27 finished with value: 8503.08798690581 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3973737958071606, 'learning_rate': 0.002198760115531647, 'regularization': 3.452521546404201e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:33:03,220] Trial 28 finished with value: 42797.04021786972 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3692926691832941, 'learning_rate': 0.0029090418996827014, 'regularization': 8.293739165058125e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:34:10,378] Trial 29 finished with value: 8292.93447403169 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4282723426541198, 'learning_rate': 0.0026494902474724635, 'regularization': 2.5451917907780584e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:35:06,177] Trial 30 finished with value: 14464.221253301057 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3412729473465085, 'learning_rate': 0.0024804727599447773, 'regularization': 5.5703660503481714e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:36:05,942] Trial 31 finished with value: 10083.623046875 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.41870415118117327, 'learning_rate': 0.0027240480234009736, 'regularization': 2.7895097855799953e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:37:16,726] Trial 32 finished with value: 8390.172824053698 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3977010316799277, 'learning_rate': 0.002286002767908126, 'regularization': 1.74450395455076e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:38:06,130] Trial 33 finished with value: 21890.862235915494 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.4222814417062732, 'learning_rate': 0.002238843871148224, 'regularization': 3.9774580269724546e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:39:16,667] Trial 34 finished with value: 9323.33632262324 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.45028677641119114, 'learning_rate': 0.0020284792203715788, 'regularization': 3.096984276464094e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:40:04,971] Trial 35 finished with value: 21853.642825704224 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3762990304804408, 'learning_rate': 0.002398731949949705, 'regularization': 2.0720756434318356e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:40:50,954] Trial 36 finished with value: 29877.708516725354 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.46226377134850205, 'learning_rate': 0.002562164681721892, 'regularization': 5.801185785811909e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:41:43,817] Trial 37 finished with value: 21966.81778169014 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.25034837188728426, 'learning_rate': 0.0021410368025247886, 'regularization': 4.6980538982149806e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:42:21,018] Trial 38 finished with value: 43552.34259463028 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.43670214565763027, 'learning_rate': 0.0023862713984259673, 'regularization': 2.9713179343162464e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:43:01,195] Trial 39 finished with value: 34119.327684859156 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3940503431865157, 'learning_rate': 0.0026944011889467774, 'regularization': 3.9284181189645595e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:44:11,683] Trial 40 finished with value: 19121.727277728874 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.41314879097412455, 'learning_rate': 0.003279636646100981, 'regularization': 2.355334392166213e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:45:05,493] Trial 41 finished with value: 20168.995185959506 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.40174324213126167, 'learning_rate': 0.002853119045865572, 'regularization': 0.00016740679458491782}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:46:08,553] Trial 42 finished with value: 9040.169467979753 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.41118811730722465, 'learning_rate': 0.002621057827699904, 'regularization': 0.00010869832846464147}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:47:16,685] Trial 43 finished with value: 7768.527756382042 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3578033914351195, 'learning_rate': 0.002475184939557604, 'regularization': 7.034377629833617e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:48:18,295] Trial 44 finished with value: 40428.38435299296 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.35386437243843194, 'learning_rate': 0.002313889574267775, 'regularization': 6.768253172684118e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:49:27,683] Trial 45 finished with value: 27487.03455105634 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.31996754467606175, 'learning_rate': 0.0024794297150750625, 'regularization': 8.147348537828337e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:50:36,925] Trial 46 finished with value: 10033.269572513203 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3797454915790656, 'learning_rate': 0.0017436294242006713, 'regularization': 5.215974630439899e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:51:45,088] Trial 47 finished with value: 7928.30449493838 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3326054937422146, 'learning_rate': 0.002378085798668168, 'regularization': 3.6015828994448344e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:52:53,963] Trial 48 finished with value: 7511.734705105634 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3006776003068115, 'learning_rate': 0.002339728888776293, 'regularization': 3.6066585551885676e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:54:00,055] Trial 49 finished with value: 12329.979670994719 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.2910467889621146, 'learning_rate': 0.0023517678509771063, 'regularization': 3.59287842727235e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:54:50,878] Trial 50 finished with value: 20043.636168573943 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.30291871886178207, 'learning_rate': 0.0022148134082815127, 'regularization': 2.7111721321810315e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:55:59,934] Trial 51 finished with value: 7713.265377420775 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.33791315950939305, 'learning_rate': 0.00246217258904498, 'regularization': 4.475689961490664e-05}. Best is trial 21 with value: 7247.111878301056.
# [I 2025-11-30 18:57:09,106] Trial 52 finished with value: 7022.391835387324 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3391463727944943, 'learning_rate': 0.0025751617905359564, 'regularization': 6.0634997790390014e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 18:58:15,490] Trial 53 finished with value: 7573.2311702244715 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.2848453126324137, 'learning_rate': 0.002579905404094723, 'regularization': 6.0837428241153815e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 18:59:21,825] Trial 54 finished with value: 14535.561564700703 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.2798677658713651, 'learning_rate': 0.002578096825589765, 'regularization': 6.087099643079413e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:00:16,955] Trial 55 finished with value: 15214.892578125 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.30585498452556487, 'learning_rate': 0.002781231802547085, 'regularization': 4.268881922683364e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:01:19,871] Trial 56 finished with value: 11569.385412081867 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.27391378301322566, 'learning_rate': 0.00272007058047283, 'regularization': 8.714005997929112e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:02:08,082] Trial 57 finished with value: 25315.068001760563 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.31381500329392464, 'learning_rate': 0.002557532965978608, 'regularization': 5.3853332164321995e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:03:05,071] Trial 58 finished with value: 17811.230771346833 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.28616061935913323, 'learning_rate': 0.0029097962893863904, 'regularization': 3.29694918171477e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:03:53,002] Trial 59 finished with value: 19506.484622579224 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.2597141400383484, 'learning_rate': 0.002673862090509429, 'regularization': 4.2971682801790124e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:05:02,389] Trial 60 finished with value: 7632.154874559859 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.34174863810095624, 'learning_rate': 0.0024330168498335946, 'regularization': 9.591893520147527e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:05:52,159] Trial 61 finished with value: 22781.168518926057 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3367456280173827, 'learning_rate': 0.002440321714623613, 'regularization': 0.00010224905275786974}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:06:57,381] Trial 62 finished with value: 14203.474251760563 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.30983584963612054, 'learning_rate': 0.0026186857981922366, 'regularization': 7.444907306008219e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:07:59,463] Trial 63 finished with value: 13382.784303477112 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.34559919984663723, 'learning_rate': 0.002518783242345056, 'regularization': 0.00012936220570896023}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:09:08,423] Trial 64 finished with value: 8809.62461487676 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.32948105636684205, 'learning_rate': 0.0022752883864082187, 'regularization': 5.8541853115763485e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:10:05,753] Trial 65 finished with value: 10289.540933098591 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.29442438970506307, 'learning_rate': 0.0023354952366133547, 'regularization': 4.929319958723358e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:11:10,077] Trial 66 finished with value: 13554.75264084507 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3625838155262157, 'learning_rate': 0.0024315236869811674, 'regularization': 6.255170198457098e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:12:14,195] Trial 67 finished with value: 8854.83252640845 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.34441584482560783, 'learning_rate': 0.0025792562759377443, 'regularization': 4.3955287079425155e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:13:23,582] Trial 68 finished with value: 12757.809556558099 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.31456284756579733, 'learning_rate': 0.002782035875805068, 'regularization': 9.183820550949725e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:14:10,058] Trial 69 finished with value: 20393.982256822183 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.48549276750829595, 'learning_rate': 0.0024950330124451376, 'regularization': 0.0001257421654145186}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:15:08,180] Trial 70 finished with value: 13519.412577024648 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3690950561047014, 'learning_rate': 0.0024466230702776368, 'regularization': 3.886222346884868e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:16:17,359] Trial 71 finished with value: 12894.219162632042 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3624779593084136, 'learning_rate': 0.002655277563772243, 'regularization': 7.208923618918393e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:17:23,478] Trial 72 finished with value: 8845.143664722711 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3276014994203147, 'learning_rate': 0.002464369280738506, 'regularization': 6.743722168193248e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:18:24,173] Trial 73 finished with value: 8558.117820202464 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.388074972853491, 'learning_rate': 0.002546997140682585, 'regularization': 5.13537169539491e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:19:25,976] Trial 74 finished with value: 13794.435326804578 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.349248130657341, 'learning_rate': 0.00237799229262722, 'regularization': 7.88595013664878e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:20:26,321] Trial 75 finished with value: 10170.69579390405 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3590055061761941, 'learning_rate': 0.002269228410513616, 'regularization': 5.6534304701753396e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:21:34,211] Trial 76 finished with value: 8493.18692231514 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.33942977046092565, 'learning_rate': 0.0021700411835635126, 'regularization': 6.922743685388493e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:22:43,463] Trial 77 finished with value: 7446.884751870599 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.30191183064970606, 'learning_rate': 0.00252458307877094, 'regularization': 4.741841364015148e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:23:52,932] Trial 78 finished with value: 15092.280479753521 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3005240603111477, 'learning_rate': 0.0025856836152126873, 'regularization': 3.2532508483862613e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:25:01,233] Trial 79 finished with value: 11473.899097711268 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.2652340601490893, 'learning_rate': 0.0025272139037585597, 'regularization': 0.00025705579432833885}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:25:57,378] Trial 80 finished with value: 9149.663828675177 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.284152793946665, 'learning_rate': 0.002745556771938802, 'regularization': 4.540905772736791e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:27:05,223] Trial 81 finished with value: 10658.477112676057 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3358435491392533, 'learning_rate': 0.002425228012664516, 'regularization': 4.8108386651099526e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:28:11,160] Trial 82 finished with value: 13604.033918353873 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.27529527175196905, 'learning_rate': 0.002496282875290592, 'regularization': 4.02152554030671e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:29:12,348] Trial 83 finished with value: 42492.073503521126 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.34980236255851305, 'learning_rate': 0.0026284115088801834, 'regularization': 6.210537857543382e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:30:13,687] Trial 84 finished with value: 9807.98037246919 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.31860824539061294, 'learning_rate': 0.002322818758146884, 'regularization': 5.425229777935848e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:31:20,431] Trial 85 finished with value: 8328.427610585388 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3235267704692603, 'learning_rate': 0.0023689392201470157, 'regularization': 9.57721325185036e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:32:21,746] Trial 86 finished with value: 15463.115206866198 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.2905900845109453, 'learning_rate': 0.002407263279935497, 'regularization': 3.6233035330702695e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:33:06,342] Trial 87 finished with value: 27328.30606294014 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3752580407220225, 'learning_rate': 0.0026868173790489613, 'regularization': 0.00015317378836530608}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:34:01,815] Trial 88 finished with value: 33282.13935959507 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.42638688883373743, 'learning_rate': 0.00246653820861544, 'regularization': 8.797150483071013e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:35:11,332] Trial 89 finished with value: 15163.182603433099 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.2989720780874708, 'learning_rate': 0.0026038910647358505, 'regularization': 0.00011006668303022606}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:36:10,722] Trial 90 finished with value: 9190.803986025529 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.30852830711621293, 'learning_rate': 0.0025089776234487934, 'regularization': 2.8718375250063754e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:37:17,024] Trial 91 finished with value: 13026.380831866198 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.33154523052756274, 'learning_rate': 0.002237956677673344, 'regularization': 3.6538588789330905e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:38:26,070] Trial 92 finished with value: 11997.982779489437 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.35587982013045805, 'learning_rate': 0.002306391231560372, 'regularization': 3.461513828168598e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:39:35,275] Trial 93 finished with value: 7789.270480303697 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.33264050285645846, 'learning_rate': 0.0023612057306946145, 'regularization': 4.121232239373217e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:40:44,460] Trial 94 finished with value: 9021.369126870599 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3250554671780509, 'learning_rate': 0.0021053883552649877, 'regularization': 4.111611448728411e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:41:51,897] Trial 95 finished with value: 42372.40729533451 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3447623737922939, 'learning_rate': 0.0025517578258085973, 'regularization': 5.053794583114995e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:42:55,643] Trial 96 finished with value: 9625.260274537852 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.43653949014086435, 'learning_rate': 0.0023513528829829326, 'regularization': 4.475925687236012e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:43:57,987] Trial 97 finished with value: 8960.679329885563 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3641035563834998, 'learning_rate': 0.0024526168427727894, 'regularization': 6.429859480194172e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:44:55,772] Trial 98 finished with value: 11234.164970290492 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.31759433548025745, 'learning_rate': 0.002388399828165036, 'regularization': 5.7711544215350834e-05}. Best is trial 52 with value: 7022.391835387324.
# [I 2025-11-30 19:46:05,070] Trial 99 finished with value: 7165.877407020246 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3353653811798862, 'learning_rate': 0.002504831251970161, 'regularization': 2.570076758418601e-05}. Best is trial 52 with value: 7022.391835387324.

# %%
# Get the best hyperparameters
best_params = study.best_params
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'hidden_size': 256, 'num_layers': 2, 'dropout_rate': 0.3391463727944943, 'learning_rate': 0.0025751617905359564, 'regularization': 6.0634997790390014e-05}

# %%
# Train the final model with the best hyperparameters
final_val_loss, best_model = train_eval(train_dataset, val_dataset,
                                        hidden_size=best_params['hidden_size'],
                                        num_layers=best_params['num_layers'],
                                        dropout_rate=best_params['dropout_rate'],
                                        learning_rate=best_params['learning_rate'],
                                        batch_size=32,
                                        regularization=best_params['regularization'],
                                        num_epochs=1000)

# %%
torch.save(best_model.state_dict(), '..\models\Mixed_cnn-lstm.pth')

# %%
# convert test data to torch tensors
X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).to(device)

# set model to evaluation mode
best_model.eval()

# initialize test loss
test_loss = 0

criterion = nn.MSELoss()

# no need to calculate gradients during testing
with torch.no_grad():
    # forward pass
    test_outputs = best_model(X_test_tensor)
    
    # calculate loss
    test_loss = criterion(test_outputs, y_test_tensor).item()

# print test loss
print(f"Test Loss: {test_loss:.4f}")
# Out:
# Test Loss: 18218.7051

# %%
# Move predictions and ground truth to CPU for visualization
pred = test_outputs[0].cpu().numpy()  # Shape: (seq_length, 9)
true = y_test_tensor[0].cpu().numpy()      # Shape: (seq_length, 9)

fig, axes = plt.subplots(3, 3, figsize=(15, 10))  # Create subplots for 9 muscles
axes = axes.flatten()

for i in range(9):
    axes[i].plot(perc_stance, true[:, i], label="True")
    axes[i].plot(perc_stance, pred[:, i], label="Predicted", linestyle='dashed')
    axes[i].set_title(muscle_dict[i])
    axes[i].set_xlabel("Percent Normalized Stance (%)")
    axes[i].set_ylabel("Muscle Force (N)")
    axes[i].legend()

plt.tight_layout()
plt.show()
